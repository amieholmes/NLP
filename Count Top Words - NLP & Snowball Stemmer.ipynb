# %%
#import libraries
from nltk.corpus import stopwords
import pandas as pd
import numpy as np

from nltk.stem import SnowballStemmer
snowball = SnowballStemmer(language='english')
from nltk.tokenize import word_tokenize

# %%
#import VoC data as dataframe
reviews_df = pd.read_csv('disney_reviews.csv', encoding='latin1')
reviews_df
# Out:
#        Review_ID  Rating Year_Month     Reviewer_Location  \
# 0      670772142       4     2019-4             Australia
# 1      670682799       4     2019-5           Philippines
# 2      670623270       4     2019-4  United Arab Emirates
# 3      670607911       4     2019-4             Australia
# 4      670607296       4     2019-4        United Kingdom
# ...          ...     ...        ...                   ...
# 42651    1765031       5    missing        United Kingdom
# 42652    1659553       5    missing                Canada
# 42653    1645894       5    missing          South Africa
# 42654    1618637       4    missing         United States
# 42655    1536786       4    missing        United Kingdom
#
#                                              Review_Text
# 0      If you've ever been to Disneyland anywhere you...
# 1      Its been a while since d last time we visit HK...
# 2      Thanks God it wasn   t too hot or too humid wh...
# 3      HK Disneyland is a great compact park. Unfortu...
# 4      the location is not in the city, took around 1...
# ...                                                  ...
# 42651  i went to disneyland paris in july 03 and thou...
# 42652  2 adults and 1 child of 11 visited Disneyland ...
# 42653  My eleven year old daughter and myself went to...
# 42654  This hotel, part of the Disneyland Paris compl...
# 42655  I went to the Disneyparis resort, in 1996, wit...
#
# [42656 rows x 5 columns]

# %%
#make text a series

reviews = reviews_df.Review_Text
reviews
# Out:
# 0        If you've ever been to Disneyland anywhere you...
# 1        Its been a while since d last time we visit HK...
# 2        Thanks God it wasn   t too hot or too humid wh...
# 3        HK Disneyland is a great compact park. Unfortu...
# 4        the location is not in the city, took around 1...
#                                ...
# 42651    i went to disneyland paris in july 03 and thou...
# 42652    2 adults and 1 child of 11 visited Disneyland ...
# 42653    My eleven year old daughter and myself went to...
# 42654    This hotel, part of the Disneyland Paris compl...
# 42655    I went to the Disneyparis resort, in 1996, wit...
# Name: Review_Text, Length: 42656, dtype: object

# %%
#create empty list and stem all words
stems = []

for word in reviews:
       stems.append(snowball.stem(word))

# %%
#import NLP packages to count words and make them into vectors

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

# %%
#fit to stemmed list
vect = CountVectorizer(stop_words='english', max_df=0.5, ngram_range=(1, 1), max_features=10000)
X_train  = vect.fit_transform(stems)

# %%
#print last 50 features out

print((vect.get_feature_names()[-50:]))
# Out:
# ['yawning', 'yay', 'yea', 'yeah', 'year', 'yearly', 'years', 'yell', 'yelled', 'yelling', 'yellow', 'yep', 'yes', 'yesterday', 'yeti', 'yi', 'yikes', 'yo', 'yoghurt', 'yoghurts', 'yogurt', 'york', 'youll', 'young', 'younger', 'youngest', 'youngster', 'youngsters', 'youre', 'youth', 'youtube', 'youve', 'yr', 'yrs', 'yuck', 'yuk', 'yum', 'yummy', 'yup', 'zealand', 'zero', 'zig', 'zip', 'zocalo', 'zombies', 'zone', 'zones', 'zoo', 'zoom', 'zurg']

# %%
#print stop words

print((vect.get_stop_words()))
# Out:
# frozenset({'anyone', 'are', 'more', 'whatever', 'on', 'him', 'thence', 'few', 'those', 'next', 'many', 'how', 'thereupon', 'move', 'therefore', 'cry', 'too', 'as', 'amount', 'they', 'themselves', 'may', 'upon', 'done', 'latter', 'was', 'amoungst', 'take', 'seemed', 'becomes', 'mill', 'side', 'two', 'somehow', 'noone', 'almost', 'none', 'eleven', 'their', 'so', 'hereby', 'after', 'con', 'herein', 'nine', 'sometime', 'anything', 'and', 'thereby', 'for', 'thus', 'meanwhile', 'whenever', 'indeed', 'ie', 'thereafter', 'himself', 'my', 'behind', 'either', 'under', 'be', 'most', 'ltd', 'wherein', 'since', 'about', 'that', 'without', 'least', 'describe', 'via', 'will', 'myself', 'who', 'there', 'must', 'before', 'below', 'nothing', 'sincere', 'often', 'once', 'between', 'ours', 'been', 'against', 'one', 'someone', 'whereby', 'serious', 'fill', 'whence', 're', 'ourselves', 'another', 'several', 'in', 'into', 'cannot', 'hereafter', 'etc', 'bill', 'had', 'found', 'both', 'onto', 'whereas', 'me', 'call', 'fire', 'hasnt', 'hereupon', 'the', 'wherever', 'than', 'hence', 'whole', 'everything', 'besides', 'his', 'again', 'now', 'although', 'hers', 'whoever', 'together', 'yourselves', 'down', 'is', 'de', 'only', 'fifteen', 'we', 'rather', 'them', 'neither', 'others', 'became', 'can', 'has', 'mostly', 'top', 'of', 'never', 'own', 'seeming', 'herself', 'nobody', 'everyone', 'give', 'would', 'not', 'well', 'name', 'with', 'namely', 'from', 'same', 'anyhow', 'empty', 'put', 'all', 'these', 'last', 'yet', 'first', 'hundred', 'whom', 'twelve', 'eg', 'throughout', 'your', 'her', 'already', 'made', 'thick', 'beside', 'toward', 'were', 'three', 'latterly', 'bottom', 'couldnt', 'through', 'am', 'due', 'each', 'or', 'former', 'enough', 'beyond', 'six', 'find', 'alone', 'therein', 'system', 'much', 'thin', 'co', 'you', 'whose', 'this', 'sometimes', 'if', 'where', 'eight', 'it', 'fifty', 'itself', 'un', 'third', 'until', 'part', 'out', 'somewhere', 'a', 'four', 'perhaps', 'inc', 'except', 'an', 'further', 'full', 'during', 'here', 'elsewhere', 'however', 'along', 'anyway', 'ever', 'else', 'nor', 'she', 'off', 'formerly', 'to', 'he', 'do', 'yours', 'back', 'i', 'no', 'show', 'though', 'nowhere', 'when', 'less', 'whereafter', 'front', 'always', 'us', 'whether', 'which', 'over', 'get', 'very', 'sixty', 'our', 'within', 'why', 'could', 'interest', 'should', 'by', 'thru', 'seems', 'five', 'such', 'amongst', 'while', 'become', 'might', 'mine', 'because', 'forty', 'towards', 'among', 'go', 'at', 'detail', 'above', 'any', 'whither', 'ten', 'its', 'please', 'per', 'keep', 'yourself', 'twenty', 'still', 'around', 'becoming', 'see', 'whereupon', 'cant', 'being', 'even', 'have', 'everywhere', 'moreover', 'nevertheless', 'some', 'but', 'every', 'beforehand', 'other', 'something', 'otherwise', 'across', 'seem', 'what', 'then', 'also', 'anywhere', 'up', 'afterwards'})

# %%
#This function gets the top 500 most frequent features that appear in the ccb reviews

def get_count_top_features(reviews,n_top=1000):
  vect = CountVectorizer(stop_words='english', max_df=0.5, ngram_range=(1, 1), max_features=1000)
  count = vect.fit_transform(stems)
  importance = np.argsort(np.asarray(count.sum(axis=0)).ravel())[::-1]
  count_feature_names = np.array(vect.get_feature_names())
  return count_feature_names[importance[:n_top]]

get_count_top_features(stems)
# Out:
# array(['disney', 'rides', 'disneyland', 'time', 'day', 'ride', 'just',
#        'great', 'food', 'kids', 'place', 'good', 'really', 'like',
#        'visit', 'went', 'people', 'long', 'fast', 'fun', 'parks', 'pass',
#        'wait', 'experience', 'times', 'days', 'did', 'parade', 'world',
#        'don', 'year', 'children', 'staff', 'characters', 'mountain',
#        'got', 'line', 'lines', 'paris', 'old', 'family', 'worth',
#        'fireworks', 'attractions', 'going', 'small', 'little', 'hotel',
#        'queues', 'best', 'lot', 'expensive', 'loved', 'trip', 'make',
#        'queue', 'minutes', 'didn', 'amazing', 'love', 'better', 'way',
#        'magic', 'big', 'early', 'closed', 'hours', 'california',
#        'visited', 'magical', 'years', 'want', 'enjoyed', 'enjoy', 'hour',
#        'night', 'tickets', '10', 'space', 'need', 'sure', 'waiting',
#        'think', 'main', 'say', 'shows', 'recommend', 'nice', 'mickey',
#        'busy', 'bit', 'new', 'come', 'money', 'took', 'lots', 'things',
#        'use', 'ticket', 'crowded', 'crowds', 'train', 'quite', 'land',
#        'passes', 'adventure', '30', 'florida', 've', 'clean', 'theme',
#        'definitely', 'castle', 'thing', 'stay', 'walk', 'able', 'spent',
#        'know', 'hong', 'kong', 'daughter', 'adults', 'open', 'having',
#        'different', 'parades', 'especially', 'water', 'end', 'friendly',
#        'feel', 'plan', 'young', 'getting', 'fantastic', 'restaurants',
#        'street', 'try', 'wonderful', 'right', 'bad', 'wanted', 'walking',
#        'eat', 'christmas', 'service', 'spend', 'half', 'disappointed',
#        'buy', 'overall', 'star', 'smaller', 'pirates', 'bring', 'stayed',
#        'fastpass', 'happy', 'meet', 'child', 'area', 'price', 'cast',
#        '20', 'expect', 'wasn', 'week', 'ones', 'said', 'saw', 'weather',
#        'pretty', 'hot', 'thunder', 'shops', 'prices', 'thought', 'lunch',
#        'holiday', 'attraction', 'easy', 'hk', 'evening', 'plenty',
#        'visiting', 'special', 'used', 'away', 'places', 'expected', 'son',
#        'morning', '15', 'left', 'll', 'members', 'entrance', 'free',
#        'studios', 'helpful', 'jones', 'character', 'walt', 'let', 'miss',
#        'huge', 'felt', 'yes', 'indiana', 'couple', 'short', 'second',
#        'inside', 'told', 'minute', 'awesome', 'orlando', 'check', 'came',
#        'look', 'mins', 'cost', 'restaurant', 'earth', 'actually',
#        'season', 'watch', 'avoid', 'probably', 'light', 'return', 'ages',
#        'kid', 'extra', 'start', 'pay', 'book', 'beautiful', 'far', 'meal',
#        'high', 'does', 'available', 'close', 'happiest', 'outside',
#        'later', 'absolutely', 'waited', 'queuing', 'popular', 'save',
#        'excellent', 'course', 'halloween', 'age', 'drinks', 'areas',
#        'french', 'haunted', 'breakfast', 'favorite', 'seen', 'help',
#        'prepared', 'break', 'arrived', 'leave', 'buzz', 'looking',
#        'truly', 'coaster', 'longer', 'lovely', 'couldn', 'taking',
#        'photo', 'princess', 'caribbean', 'summer', 'drink', 'staying',
#        'ok', 'late', 'managed', 'maybe', 'photos', '45', 'work',
#        'husband', 'crowd', 'rest', 'bought', 'mouse', 'hotels', 'near',
#        'weekend', 'room', 'euros', 'single', 'station', 'birthday',
#        'compared', 'dinner', 'rude', 'perfect', 'afternoon', 'decided',
#        'twice', 'app', 'snacks', 'plus', 'quality', 'adult', 'hopper',
#        'hard', 'story', 'anaheim', 'home', 'parking', 'highly', 'sit',
#        'ago', 'number', 'point', 'stand', 'makes', 'missed', 'doesn',
#        'run', 'real', 'cars', 'roller', 'weren', 'mansion', 'life',
#        'wife', 'won', 'seeing', 'person', 'atmosphere', 'remember',
#        'spot', 'cold', 'favourite', '00', '12', '11', 'peter', 'booked',
#        'original', '40', 'disneyworld', 'options', 'princesses',
#        'possible', 'soon', 'brilliant', 'disappointing', 'past', 'doing',
#        'wars', 'pan', 'tired', 'live', 'extremely', 'isn', 'resort',
#        'allowed', 'stop', 'visitors', 'school', 'guests', 'older', 'paid',
#        'smoking', 'packed', 'entire', 'splash', 'tours', 'enter',
#        'started', 'opened', 'given', '50', 'friends', 'entry', 'security',
#        'taken', 'car', 'english', 'enjoyable', 'coming', 'pictures',
#        'offer', 'toy', 'super', 'bus', 'holidays', 'opening', 'fact',
#        'walked', 'view', 'needs', 'king', 'instead', 'problem', 'large',
#        'families', 'value', 'cool', 'memories', 'trying', 'dreams',
#        'access', 'wish', 'spectacular', 'euro', 'wouldn', 'poor',
#        'planning', 'gets', '60', 'usa', 'standing', 'village', 'minnie',
#        'mtr', 'average', 'straight', 'online', 'mind', 'set', 'kingdom',
#        'party', 'including', 'pm', 'parents', 'member', 'younger', 'gone',
#        'fan', 'min', 'easily', 'lightyear', 'tip', 'forget',
#        'fantasyland', 'overpriced', 'rain', 'review', 'tried', 'lion',
#        'display', 'unfortunately', 'cafe', 'option', 'despite', 'dont',
#        'closing', 'cheaper', 'usually', 'making', 'liked', 'ate', 'using',
#        'true', 'understand', 'kept', 'advance', 'head', 'asked',
#        'finally', 'shop', 'surprised', 'annual', 'looked', 'choice',
#        'dream', 'gave', 'priced', 'excited', 'working', 'matterhorn',
#        'firework', 'glad', 'kind', 'wrong', 'needed', 'shopping', 'blast',
#        'advantage', 'quickly', 'toilets', 'pricey', 'travel', 'manor',
#        'limited', 'tour', 'believe', 'totally', 'peak', 'unless', 'group',
#        'cheap', 'ask', 'longest', 'vacation', 'meals', 'watching',
#        'suggest', 'size', 'wdw', 'major', 'la', 'stuff', 'lack', 'themed',
#        'gates', 'anniversary', 'customer', 'house', 'matter', 'simply',
#        'reviews', 'idea', 'disappointment', 'waste', 'city', 'broke',
#        'thrill', 'takes', 'brought', 'eating', 'certainly', 'round',
#        'gate', 'map', 'tell', 'tower', 'grizzly', 'lucky', 'ahead',
#        'whilst', 'read', 'tips', 'quick', 'arrive', '90', 'reason',
#        'shuttle', 'queued', 'chance', 'music', 'snow', 'till', 'ended',
#        'mid', 'knew', 'nearly', 'site', 'entertainment', 'order', 'ice',
#        'picture', 'shut', 'hand', 'fantasy', 'studio', 'deal', 'crazy',
#        'downtown', 'fantasmic', 'fine', 'stroller', 'feeling', 'change',
#        'waits', 'certain', 'choose', 'running', 'meant', 'childhood',
#        'employees', '25', 'advice', 'nights', 'usual', 'souvenirs',
#        'shorter', 'returned', 'forward', 'care', 'exciting', 'works',
#        'rode', 'goes', 'cruise', 'american', 'mystic', 'bigger', 'hit',
#        'met', 'compare', 'monday', 'opens', 'lost', 'merchandise', 'oh',
#        '100', 'attention', 'maintenance', 'girls', 'track', 'meeting',
#        'expectations', 'decorations', 'moment', 'heat', 'man', 'called',
#        'jungle', 'similar', 'hope', 'face', '10am', 'allow', 'highlight',
#        'worked', 'terror', 'aren', 'completely', 'ca', 'guess',
#        'hollywood', 'fabulous', 'included', 'reasonable', 'bag', 'beauty',
#        'note', 'board', 'earlier', 'cover', 'lights', 'shoes', 'changed',
#        'purchase', 'saturday', 'friday', 'spending', 'paying', 'website',
#        'ready', 'dining', 'buffet', 'tea', 'quiet', 'slow', 'sunday',
#        'smile', 'august', 'difficult', 'expecting', 'purchased',
#        'universal', 'baby', 'ridiculous', 'bottle', 'wear', 'frozen',
#        'saying', 'france', 'sun', 'bags', 'experienced', 'tomorrowland',
#        'version', 'worst', 'problems', 'loads', 'pick', 'dumbo',
#        'comfortable', 'obviously', 'non', 'chinese', 'phone', 'aged',
#        'strollers', 'broken', 'months', 'table', 'general', 'impressed',
#        'incredible', 'pushing', 'wow', 'complete', 'planned', 'dlp',
#        'scary', 'spring', 'public', 'amusement', 'issue', 'grand', 'list',
#        'tokyo', 'blue', 'sleeping', 'coffee', 'boys', 'dark', 'october',
#        'case', 'pooh', 'looks', 'girl', 'easier', 'low', 'opinion',
#        'july', 'turn', 'means', 'noticed', 'skip', 'admission', 'biggest',
#        'treat', 'weekday', 'hardly', 'heart', 'daughters', 'watched',
#        'shame', 'white', 'turned', 'variety', 'difference', 'cream',
#        'hall', 'various', 'leaving', 'rider', 'heard', 'dl', 'play',
#        'recommended', 'town', 'refurbishment', 'fastpasses', 'pleasant',
#        '30pm', 'month', 'buying', 'weekends', 'total', 'card', 'bottles',
#        'cut', 'boat', 'apart', 'literally', 'generally', 'example',
#        'middle', 'job', 'sad', 'haven', 'mean', 'airport', 'visits',
#        'didnt', 'interesting', 'warm', 'massive', 'particularly',
#        'starts', 'surprise', 'saved', 'standard', 'disabled', 'decent',
#        'imagine', 'experiences', 'bay', 'railroad', 'thank',
#        'considering', 'guest', 'normal', 'friend', 'slightly', 'catch',
#        '13', 'seats', 'comes', 'activities', 'costs', 'ratatouille',
#        'store', 'goofy', 'terrible', 'que', 'multiple', 'information',
#        'december', 'paint', 'river', 'flight', 'bother', 'push',
#        'facilities', 'fans', 'technical', 'opportunity', 'negative',
#        'issues', 'fountains', 'maintained', 'fair', 'add', 'items',
#        'speak', 'sunny', 'awful', 'europe', 'pre', 'adventureland',
#        'booking', 'basically', 'helped', 'local', 'filled', 'hyperspace',
#        'missing', 'unique', 'thoroughly', '14', 'location', 'max',
#        'aware', 'uk', 'nemo', 'faces', 'burger', 'january', 'event',
#        'package', 'finding', 'comparison', 'classic', 'stopped', 'guide',
#        'offered', 'moving', 'smoke', 'pizza', 'recently', 'rush', 'feet',
#        'chicken', 'pack', 'seat', 'movie', 'happened', 'vouchers',
#        'consider', 'june', 'boy', 'ocean', 'worse', 'chips', '2nd',
#        'teenagers', 'riding', 'winnie', 'drop', '1st', 'gives',
#        'reservations', 'stood', 'mor', 'manage', 'travelling', 'america',
#        'september', 'parts', 'thinking', 'march', 'added', 'grown',
#        'frontierland', 'snack', 'winter', 'sign', 'honestly', 'stores',
#        'budget', 'prior', 'hongkong', 'lands', 'enjoying', 'wheelchair',
#        'carry', 'alot', 'exit', 'previous', 'stars', 'color', 'eyes',
#        'travelled', '70', 'charge', 'control', 'notice', 'safe', 'crush',
#        'tuesday', 'headed', 'rooms', 'door', 'plaza', 'wet', 'thursday',
#        'autopia', 'choices', 'research', 'sorry', 'gift', 'ups', 'golden',
#        'wild', 'air', 'dirty', 'greet', 'regular', 'seating', 'lifetime',
#        'gulch', 'excitement', 'cute', 'sell', 'offers', 'ques', 'type',
#        'grab', 'signs', 'suitable', 'level', 'november', 'downside',
#        'polite', 'fairly', 'decorated', '3rd', 'disappoint', 'organised',
#        'sort', 'happen', 'points', 'memorable', 'future', 'alice',
#        'advise', 'impossible', 'laser', 'fault', 'sat', 'cinderella',
#        'nightmare', 'management', 'based', 'april', 'entering',
#        'schedule', 'closes', 'drive', '80', 'discount', 'mainly', 'tram',
#        'download', 'chose', 'coasters', 'style', 'important', 'unlike',
#        'complaint', 'returning', 'grandchildren', 'bored', 'sitting',
#        'explore', 'outlets', 'dog', 'details', 'okay'], dtype='<U14')

# %%
#counts the top 1000 features
reviews = stems
n_top=1000  # was 500

vect = CountVectorizer(stop_words='english', max_df=0.5, ngram_range=(1, 1), max_features=10000)
count = vect.fit_transform(reviews)
importance = np.argsort(np.asarray(count.sum(axis=0)).ravel())[::-1]
count_feature_names = np.array(vect.get_feature_names())
count_feature_names[importance[:n_top]]
# Out:
# array(['disney', 'rides', 'disneyland', 'time', 'day', 'ride', 'just',
#        'great', 'food', 'kids', 'place', 'good', 'really', 'like',
#        'visit', 'went', 'people', 'long', 'fast', 'fun', 'parks', 'pass',
#        'wait', 'experience', 'times', 'days', 'did', 'parade', 'world',
#        'don', 'year', 'children', 'staff', 'characters', 'mountain',
#        'got', 'line', 'lines', 'paris', 'old', 'family', 'worth',
#        'fireworks', 'attractions', 'going', 'small', 'little', 'hotel',
#        'queues', 'best', 'lot', 'expensive', 'loved', 'trip', 'make',
#        'queue', 'minutes', 'didn', 'amazing', 'love', 'better', 'way',
#        'magic', 'big', 'early', 'closed', 'hours', 'california',
#        'visited', 'magical', 'years', 'want', 'enjoyed', 'enjoy', 'hour',
#        'night', 'tickets', '10', 'space', 'need', 'sure', 'waiting',
#        'think', 'main', 'say', 'shows', 'recommend', 'nice', 'mickey',
#        'busy', 'bit', 'new', 'come', 'money', 'took', 'lots', 'things',
#        'use', 'ticket', 'crowded', 'crowds', 'train', 'quite', 'land',
#        'passes', 'adventure', '30', 'florida', 've', 'clean', 'theme',
#        'definitely', 'castle', 'thing', 'stay', 'walk', 'able', 'spent',
#        'know', 'hong', 'kong', 'daughter', 'adults', 'open', 'having',
#        'different', 'parades', 'especially', 'water', 'end', 'friendly',
#        'feel', 'plan', 'young', 'getting', 'fantastic', 'restaurants',
#        'street', 'try', 'wonderful', 'right', 'bad', 'walking', 'wanted',
#        'eat', 'christmas', 'service', 'spend', 'half', 'disappointed',
#        'buy', 'overall', 'star', 'smaller', 'pirates', 'bring', 'stayed',
#        'fastpass', 'happy', 'meet', 'child', 'area', 'price', 'cast',
#        '20', 'expect', 'wasn', 'week', 'ones', 'said', 'saw', 'weather',
#        'pretty', 'hot', 'thunder', 'shops', 'prices', 'thought', 'lunch',
#        'holiday', 'attraction', 'easy', 'hk', 'evening', 'plenty',
#        'visiting', 'special', 'used', 'away', 'places', 'expected', 'son',
#        'morning', '15', 'left', 'll', 'members', 'entrance', 'free',
#        'studios', 'helpful', 'jones', 'character', 'walt', 'let', 'huge',
#        'miss', 'felt', 'yes', 'indiana', 'couple', 'short', 'second',
#        'inside', 'told', 'minute', 'awesome', 'orlando', 'check', 'came',
#        'look', 'mins', 'cost', 'restaurant', 'earth', 'actually',
#        'season', 'watch', 'avoid', 'probably', 'light', 'return', 'ages',
#        'kid', 'extra', 'start', 'pay', 'book', 'beautiful', 'far', 'meal',
#        'high', 'does', 'available', 'close', 'happiest', 'outside',
#        'later', 'absolutely', 'waited', 'popular', 'queuing', 'save',
#        'excellent', 'course', 'halloween', 'age', 'drinks', 'areas',
#        'french', 'haunted', 'breakfast', 'favorite', 'seen', 'help',
#        'prepared', 'arrived', 'break', 'leave', 'buzz', 'looking',
#        'truly', 'coaster', 'longer', 'lovely', 'couldn', 'taking',
#        'photo', 'princess', 'caribbean', 'summer', 'drink', 'staying',
#        'ok', 'late', 'managed', 'maybe', 'photos', '45', 'work',
#        'husband', 'crowd', 'rest', 'bought', 'mouse', 'hotels', 'near',
#        'weekend', 'euros', 'room', 'single', 'station', 'birthday',
#        'compared', 'dinner', 'rude', 'perfect', 'afternoon', 'decided',
#        'twice', 'app', 'snacks', 'plus', 'quality', 'hopper', 'adult',
#        'hard', 'story', 'anaheim', 'home', 'highly', 'parking', 'sit',
#        'ago', 'number', 'point', 'stand', 'makes', 'missed', 'doesn',
#        'run', 'real', 'cars', 'weren', 'roller', 'mansion', 'life',
#        'wife', 'won', 'seeing', 'person', 'atmosphere', 'remember',
#        'spot', 'favourite', 'cold', '00', '11', '12', 'peter', 'booked',
#        'original', '40', 'disneyworld', 'options', 'princesses',
#        'possible', 'soon', 'brilliant', 'disappointing', 'past', 'wars',
#        'doing', 'pan', 'live', 'tired', 'extremely', 'isn', 'resort',
#        'allowed', 'stop', 'visitors', 'school', 'guests', 'older', 'paid',
#        'smoking', 'packed', 'entire', 'splash', 'tours', 'enter',
#        'started', 'opened', 'given', '50', 'friends', 'entry', 'security',
#        'taken', 'car', 'english', 'enjoyable', 'coming', 'pictures',
#        'offer', 'toy', 'super', 'bus', 'holidays', 'opening', 'fact',
#        'walked', 'view', 'needs', 'king', 'instead', 'problem', 'large',
#        'families', 'value', 'cool', 'memories', 'trying', 'dreams',
#        'access', 'wish', 'spectacular', 'euro', 'wouldn', 'poor',
#        'planning', 'gets', '60', 'usa', 'standing', 'village', 'minnie',
#        'average', 'mtr', 'straight', 'mind', 'online', 'set', 'kingdom',
#        'party', 'parents', 'pm', 'including', 'younger', 'member', 'gone',
#        'fan', 'min', 'easily', 'lightyear', 'tip', 'rain', 'forget',
#        'overpriced', 'fantasyland', 'review', 'tried', 'lion', 'display',
#        'unfortunately', 'cafe', 'option', 'dont', 'despite', 'cheaper',
#        'closing', 'usually', 'making', 'liked', 'ate', 'using', 'true',
#        'understand', 'kept', 'head', 'advance', 'asked', 'finally',
#        'shop', 'surprised', 'annual', 'looked', 'dream', 'choice',
#        'priced', 'gave', 'excited', 'working', 'matterhorn', 'firework',
#        'glad', 'kind', 'wrong', 'shopping', 'needed', 'advantage',
#        'blast', 'pricey', 'toilets', 'quickly', 'travel', 'manor',
#        'limited', 'tour', 'believe', 'totally', 'peak', 'unless', 'group',
#        'cheap', 'ask', 'longest', 'vacation', 'meals', 'suggest',
#        'watching', 'size', 'major', 'wdw', 'la', 'stuff', 'lack',
#        'themed', 'gates', 'anniversary', 'house', 'customer', 'matter',
#        'simply', 'reviews', 'idea', 'disappointment', 'waste', 'city',
#        'broke', 'thrill', 'takes', 'brought', 'eating', 'certainly',
#        'round', 'map', 'gate', 'tell', 'tower', 'grizzly', 'lucky',
#        'ahead', 'whilst', 'read', 'tips', 'quick', 'arrive', '90',
#        'reason', 'shuttle', 'queued', 'chance', 'music', 'snow', 'till',
#        'ended', 'mid', 'knew', 'site', 'nearly', 'entertainment', 'order',
#        'ice', 'shut', 'picture', 'hand', 'fantasy', 'studio', 'deal',
#        'crazy', 'downtown', 'fantasmic', 'fine', 'stroller', 'change',
#        'feeling', 'waits', 'certain', 'choose', 'running', 'meant',
#        'childhood', 'employees', '25', 'advice', 'nights', 'shorter',
#        'usual', 'souvenirs', 'forward', 'returned', 'care', 'exciting',
#        'works', 'rode', 'goes', 'cruise', 'american', 'mystic', 'bigger',
#        'hit', 'met', 'compare', 'monday', 'opens', 'lost', 'merchandise',
#        'oh', '100', 'attention', 'maintenance', 'girls', 'track',
#        'expectations', 'meeting', 'decorations', 'moment', 'man', 'heat',
#        'called', 'jungle', 'similar', 'hope', 'face', '10am', 'allow',
#        'highlight', 'worked', 'terror', 'aren', 'completely', 'ca',
#        'guess', 'fabulous', 'hollywood', 'included', 'bag', 'reasonable',
#        'beauty', 'note', 'earlier', 'board', 'cover', 'lights', 'changed',
#        'shoes', 'purchase', 'saturday', 'friday', 'paying', 'spending',
#        'website', 'ready', 'tea', 'dining', 'buffet', 'quiet', 'slow',
#        'august', 'smile', 'sunday', 'difficult', 'purchased', 'expecting',
#        'universal', 'baby', 'ridiculous', 'wear', 'bottle', 'frozen',
#        'saying', 'france', 'bags', 'sun', 'experienced', 'tomorrowland',
#        'version', 'worst', 'problems', 'loads', 'pick', 'dumbo',
#        'comfortable', 'obviously', 'non', 'phone', 'chinese', 'aged',
#        'strollers', 'broken', 'table', 'months', 'general', 'impressed',
#        'pushing', 'incredible', 'wow', 'complete', 'scary', 'dlp',
#        'planned', 'spring', 'public', 'amusement', 'issue', 'grand',
#        'list', 'blue', 'tokyo', 'sleeping', 'coffee', 'dark', 'boys',
#        'october', 'pooh', 'case', 'girl', 'looks', 'easier', 'low',
#        'july', 'opinion', 'turn', 'means', 'noticed', 'skip', 'admission',
#        'treat', 'biggest', 'heart', 'weekday', 'hardly', 'daughters',
#        'watched', 'shame', 'variety', 'white', 'difference', 'turned',
#        'cream', 'hall', 'various', 'rider', 'leaving', 'dl', 'heard',
#        'recommended', 'play', 'refurbishment', 'town', 'fastpasses',
#        '30pm', 'pleasant', 'month', 'buying', 'total', 'weekends', 'card',
#        'bottles', 'boat', 'cut', 'apart', 'generally', 'literally',
#        'example', 'middle', 'sad', 'haven', 'job', 'mean', 'visits',
#        'airport', 'interesting', 'didnt', 'massive', 'warm',
#        'particularly', 'starts', 'surprise', 'saved', 'standard',
#        'disabled', 'decent', 'imagine', 'bay', 'experiences', 'railroad',
#        'thank', 'considering', 'guest', 'friend', 'slightly', 'catch',
#        'normal', '13', 'seats', 'activities', 'ratatouille', 'costs',
#        'comes', 'terrible', 'goofy', 'store', 'multiple', 'que',
#        'december', 'information', 'paint', 'river', 'flight', 'bother',
#        'push', 'facilities', 'fans', 'technical', 'opportunity', 'issues',
#        'negative', 'fountains', 'maintained', 'fair', 'add', 'items',
#        'speak', 'awful', 'sunny', 'europe', 'pre', 'adventureland',
#        'booking', 'basically', 'helped', 'filled', 'local', 'hyperspace',
#        'thoroughly', 'missing', 'unique', 'location', '14', 'aware',
#        'max', 'nemo', 'uk', 'january', 'faces', 'burger', 'event',
#        'finding', 'package', 'comparison', 'classic', 'stopped', 'guide',
#        'offered', 'moving', 'smoke', 'pizza', 'recently', 'feet', 'rush',
#        'chicken', 'seat', 'pack', 'movie', 'vouchers', 'happened',
#        'consider', 'june', 'ocean', 'boy', 'chips', 'worse', '2nd',
#        'teenagers', 'riding', 'drop', 'winnie', 'gives', '1st', 'stood',
#        'reservations', 'manage', 'mor', 'september', 'america',
#        'travelling', 'parts', 'thinking', 'added', 'march', 'grown',
#        'frontierland', 'snack', 'winter', 'sign', 'honestly', 'stores',
#        'budget', 'prior', 'hongkong', 'lands', 'enjoying', 'wheelchair',
#        'alot', 'carry', 'exit', 'stars', 'previous', 'eyes', 'color',
#        'travelled', '70', 'control', 'charge', 'safe', 'notice', 'crush',
#        'tuesday', 'rooms', 'headed', 'door', 'thursday', 'wet', 'plaza',
#        'autopia', 'choices', 'research', 'sorry', 'ups', 'gift', 'golden',
#        'regular', 'air', 'wild', 'dirty', 'greet', 'seating', 'lifetime',
#        'gulch', 'excitement', 'cute', 'sell', 'offers', 'ques', 'type',
#        'grab', 'signs', 'level', 'suitable', 'november', 'downside',
#        'fairly', 'polite', '3rd', 'decorated', 'disappoint', 'organised',
#        'happen', 'sort', 'points', 'future', 'memorable', 'alice', 'sat',
#        'impossible', 'advise', 'laser', 'fault', 'cinderella',
#        'nightmare', 'management', 'based', 'entering', 'april',
#        'schedule', 'closes', '80', 'drive', 'mainly', 'discount', 'chose',
#        'tram', 'download', 'style', 'coasters', 'important', 'returning',
#        'complaint', 'unlike', 'bored', 'grandchildren', 'explore',
#        'sitting', 'dog', 'outlets', 'details', 'thrilling'], dtype='<U15')

# %%
vect = CountVectorizer(stop_words='english', max_df=0.5, ngram_range=(1, 1), max_features=10000)
vect
# Out:
# CountVectorizer(max_df=0.5, max_features=10000, stop_words='english')

# %%
count = vect.fit_transform(reviews)

count
# Out:
# <42656x10000 sparse matrix of type '<class 'numpy.int64'>'
# 	with 1947068 stored elements in Compressed Sparse Row format>

# %%
vect.vocabulary_
# Out:
# {'ve': 9551,
#  'disneyland': 2872,
#  'll': 5334,
#  'hong': 4508,
#  'kong': 5108,
#  'similar': 8040,
#  'layout': 5194,
#  'walk': 9671,
#  'main': 5471,
#  'street': 8547,
#  'familiar': 3578,
#  'feel': 3665,
#  'rides': 7521,
#  'small': 8136,
#  'world': 9912,
#  'absolutely': 402,
#  'fabulous': 3530,
#  'worth': 9922,
#  'doing': 2948,
#  'day': 2551,
#  'visited': 9624,
#  'fairly': 3563,
#  'hot': 4553,
#  'relatively': 7291,
#  'busy': 1523,
#  'queues': 7048,
#  'moved': 5884,
#  'time': 9044,
#  'visit': 9623,
#  'hk': 4465,
#  'stay': 8457,
#  'tomorrowland': 9105,
#  'aka': 611,
#  'marvel': 5560,
#  'land': 5142,
#  'iron': 4914,
#  'man': 5506,
#  'experience': 3472,
#  'newly': 6022,
#  'open': 6202,
#  'ant': 739,
#  'wasp': 9724,
#  'ironman': 4917,
#  'great': 4196,
#  'feature': 3654,
#  'exciting': 3411,
#  'especially': 3321,
#  'scenery': 7740,
#  'central': 1738,
#  'area': 817,
#  'kowloon': 5110,
#  'changed': 1767,
#  'previous': 6848,
#  'buzz': 1534,
#  'lightyear': 5279,
#  'expecting': 3460,
#  'boys': 1380,
#  'like': 5281,
#  'space': 8269,
#  'mountain': 5874,
#  'turns': 9303,
#  'star': 8425,
#  'wars': 9714,
#  'cast': 1683,
#  'members': 5650,
#  'staffs': 8393,
#  'felt': 3673,
#  'bit': 1240,
#  'minus': 5765,
#  'point': 6686,
#  'just': 5033,
#  'disney': 2870,
#  'brand': 1387,
#  'local': 5343,
#  'ocean': 6152,
#  'worst': 9921,
#  'got': 4146,
#  'smiling': 8156,
#  'face': 3533,
#  'wanna': 9694,
#  'enter': 3262,
#  'attraction': 942,
#  'leave': 5216,
#  'hello': 4405,
#  'supposed': 8708,
#  'happiest': 4324,
#  'place': 6624,
#  'earth': 3103,
#  'really': 7167,
#  'dont': 2958,
#  'bakery': 1051,
#  'attractive': 945,
#  'theme': 8947,
#  'sweets': 8761,
#  'good': 4131,
#  'points': 6691,
#  'starbucks': 8426,
#  'inside': 4822,
#  'thanks': 8935,
#  'god': 4117,
#  'wasn': 9722,
#  'humid': 4587,
#  'visiting': 9625,
#  'big': 1218,
#  'issue': 4931,
#  'lot': 5395,
#  'shade': 7905,
#  'arrived': 848,
#  '10': 16,
#  '30am': 207,
#  'left': 5220,
#  '6pm': 322,
#  'unfortunately': 9389,
#  'didn': 2749,
#  'evening': 3360,
#  'parade': 6395,
#  'hours': 4562,
#  'plenty': 6669,
#  'interesting': 4869,
#  'enjoy': 3246,
#  'extremely': 3523,
#  'longest': 5370,
#  'queue': 7045,
#  'certain': 1748,
#  'attractions': 943,
#  '45': 255,
#  'minutes': 5769,
#  'bad': 1039,
#  'amazing': 669,
#  'underwhelmed': 9376,
#  'choice': 1873,
#  'quite': 7063,
#  'grand': 4167,
#  'castle': 1685,
#  'closed': 1974,
#  'way': 9749,
#  'food': 3835,
#  'options': 6235,
#  'coffee': 2018,
#  'shops': 7962,
#  'including': 4729,
#  'gift': 4080,
#  'toilets': 9090,
#  'enjoyed': 3248,
#  'compact': 2095,
#  'maintenance': 5483,
#  'work': 9904,
#  'going': 4123,
#  'present': 6820,
#  'number': 6101,
#  'areas': 818,
#  'famous': 3582,
#  'midweek': 5722,
#  'crowded': 2425,
#  'certainly': 1749,
#  'near': 5975,
#  'bus': 1513,
#  'la': 5114,
#  'did': 2748,
#  'notice': 6079,
#  'prices': 6854,
#  'drinks': 3040,
#  'gone': 4128,
#  'roof': 7584,
#  'prepared': 6815,
#  'pay': 6478,
#  'dollar': 2951,
#  'snacks': 8170,
#  'avoid': 995,
#  'souvenir': 8264,
#  'regardless': 7265,
#  'kids': 5061,
#  'love': 5407,
#  'location': 5349,
#  'city': 1917,
#  'took': 9111,
#  'hour': 4560,
#  'fine': 3721,
#  'anaheim': 692,
#  'tokyo': 9092,
#  'called': 1568,
#  'souvenirs': 8265,
#  'entrance': 3287,
#  'tickets': 9026,
#  'slightly': 8114,
#  'expensive': 3468,
#  'basically': 1102,
#  'children': 1853,
#  'people': 6499,
#  'choices': 1874,
#  'acceptable': 418,
#  'fast': 3614,
#  'bottled': 1356,
#  'water': 9734,
#  'fountains': 3891,
#  'refill': 7234,
#  'bottles': 1359,
#  'pretty': 6839,
#  'problem': 6889,
#  'rude': 7614,
#  'pushing': 7012,
#  'shoving': 7982,
#  'cutting': 2490,
#  'lines': 5301,
#  'stands': 8421,
#  'forget': 3862,
#  'trying': 9277,
#  'shows': 7989,
#  'free': 3915,
#  'seats': 7803,
#  'don': 2954,
#  'let': 5243,
#  'happen': 4318,
#  'far': 3601,
#  'managed': 5510,
#  'property': 6947,
#  'won': 9884,
#  'know': 5098,
#  'obviously': 6138,
#  'went': 9795,
#  'daughter': 2543,
#  'loved': 5408,
#  'canceled': 1590,
#  'think': 8965,
#  'intro': 4886,
#  'magic': 5459,
#  'little': 5324,
#  'ones': 6193,
#  'completed': 2126,
#  '5days': 296,
#  'drawback': 3012,
#  'timing': 9056,
#  'example': 3385,
#  'storybook': 8525,
#  'theatre': 8940,
#  'wed': 9771,
#  'thu': 9006,
#  'private': 6882,
#  'events': 3364,
#  'restaurants': 7443,
#  'close': 1973,
#  'mid': 5716,
#  'week': 9778,
#  'tue': 9288,
#  'thur': 9014,
#  'best': 1205,
#  'plan': 6631,
#  'biggest': 1220,
#  'disappointment': 2818,
#  'maxim': 5597,
#  'decent': 2581,
#  'restaurant': 7442,
#  'corner': 2293,
#  'cafe': 1549,
#  'typical': 9321,
#  'abrupt': 397,
#  'hongkong': 4509,
#  'style': 8607,
#  'service': 7882,
#  'serving': 7886,
#  'staff': 8390,
#  'train': 9179,
#  'fantastic': 3596,
#  'past': 6449,
#  'station': 8450,
#  'signage': 8021,
#  'terrible': 8913,
#  'want': 9695,
#  'working': 9908,
#  'map': 5536,
#  'priced': 6852,
#  'fun': 3972,
#  'characters': 1779,
#  'seen': 7826,
#  'having': 4356,
#  'photos': 6566,
#  'visitors': 9627,
#  'queuing': 7049,
#  'rain': 7090,
#  'waste': 9727,
#  'money': 5824,
#  'walt': 9686,
#  'horrified': 4539,
#  'eating': 3121,
#  'places': 6626,
#  'rest': 7439,
#  'rooms': 7586,
#  'building': 1480,
#  'knows': 5104,
#  'atmosphere': 914,
#  'fantasy': 3598,
#  'talking': 8814,
#  'say': 7713,
#  'childhood': 1849,
#  'dreams': 3026,
#  'come': 2059,
#  'true': 9269,
#  'starting': 8437,
#  'environment': 3294,
#  'popcorn': 6716,
#  'mtr': 5897,
#  'trains': 9183,
#  'specially': 8293,
#  'designed': 2697,
#  'opinion': 6218,
#  'ticket': 9023,
#  'explore': 3491,
#  'remain': 7314,
#  'incomplete': 4734,
#  'online': 6196,
#  'save': 7703,
#  'hkd': 4466,
#  '100': 17,
#  'comparison': 2107,
#  'spot': 8355,
#  'miss': 5777,
#  'include': 4726,
#  'jungle': 5026,
#  'river': 7547,
#  'cruise': 2434,
#  'micky': 5713,
#  '4d': 268,
#  'lion': 5309,
#  'king': 5073,
#  'better': 1208,
#  'home': 4496,
#  'regarding': 7264,
#  'timings': 9057,
#  'maximise': 5598,
#  'cover': 2351,
#  'sundays': 8678,
#  'public': 6975,
#  'holidays': 4487,
#  'rush': 7635,
#  'amaze': 665,
#  'florida': 3797,
#  'thought': 8981,
#  'exhausted': 3427,
#  'kid': 5053,
#  'nope': 6061,
#  'dl': 2926,
#  'spent': 8316,
#  'grown': 4238,
#  'admit': 514,
#  'tire': 9070,
#  'aren': 819,
#  'states': 8446,
#  'parks': 6413,
#  'haunted': 4351,
#  'house': 4563,
#  'catch': 1692,
#  'list': 5312,
#  'lots': 5397,
#  'spend': 8312,
#  'course': 2341,
#  'days': 2553,
#  'second': 7807,
#  'early': 3099,
#  'straight': 8530,
#  'lineups': 5303,
#  'twice': 9312,
#  'row': 7605,
#  'suitable': 8656,
#  'young': 9973,
#  'disappointing': 2816,
#  'nightly': 6041,
#  'fireworks': 3735,
#  'season': 7795,
#  'family': 3580,
#  'birthday': 1234,
#  'memorable': 5655,
#  'huge': 4575,
#  'definately': 2619,
#  'need': 5986,
#  'aged': 575,
#  '11': 38,
#  'variety': 9545,
#  'ages': 581,
#  '3d': 232,
#  'models': 5809,
#  'ordering': 6244,
#  'helpful': 4410,
#  'awesome': 1012,
#  'brought': 1442,
#  'price': 6851,
#  'advise': 548,
#  'look': 5375,
#  'deal': 2564,
#  'refurbished': 7255,
#  'weekday': 9779,
#  '30': 204,
#  'min': 5736,
#  'wait': 9662,
#  'recommend': 7200,
#  'weekends': 9782,
#  'said': 7653,
#  'general': 4045,
#  'drink': 3038,
#  'easily': 3108,
#  'pass': 6435,
#  'scenes': 7741,
#  'movies': 5890,
#  'fairytales': 3568,
#  'pm': 6680,
#  'character': 1778,
#  '60': 306,
#  'person': 6527,
#  'eat': 3114,
#  'cost': 2306,
#  'fortune': 3883,
#  'assume': 893,
#  'half': 4286,
#  'ride': 7517,
#  'construction': 2218,
#  'doesn': 2944,
#  'finished': 3727,
#  'soon': 8228,
#  'track': 9163,
#  'single': 8060,
#  'rider': 7519,
#  'faster': 3615,
#  'average': 991,
#  'does': 2943,
#  'reviewing': 7500,
#  'speaks': 8291,
#  'smaller': 8137,
#  'expected': 3458,
#  'experi': 3470,
#  'child': 1848,
#  'step': 8476,
#  'easy': 3112,
#  'dedicated': 2607,
#  'trams': 9186,
#  'subway': 8627,
#  'stations': 8453,
#  'sunset': 8685,
#  'definitely': 2626,
#  'waiting': 9666,
#  'bought': 1360,
#  'tourist': 9145,
#  'klook': 5084,
#  'value': 9533,
#  'bearings': 1130,
#  'missed': 5778,
#  'favourite': 3643,
#  'means': 5620,
#  'parades': 6396,
#  'saw': 7710,
#  'moana': 5799,
#  'mickey': 5710,
#  'wondrous': 9895,
#  'book': 1328,
#  'works': 9910,
#  'isn': 4928,
#  'visible': 9619,
#  'magical': 5460,
#  'fan': 3583,
#  'live': 5329,
#  '20': 129,
#  'california': 1565,
#  'haven': 4354,
#  'years': 9956,
#  'vacation': 9513,
#  'able': 392,
#  'getting': 4071,
#  'downtown': 2994,
#  'super': 8687,
#  'impressed': 4699,
#  'takes': 8806,
#  'decked': 2592,
#  'themes': 8952,
#  'okay': 6183,
#  'compared': 2104,
#  'kinda': 5069,
#  'sucks': 8636,
#  'run': 7627,
#  'wednesday': 9773,
#  'slow': 8125,
#  'idea': 4635,
#  'nice': 6029,
#  'thrill': 8991,
#  'seekers': 7823,
#  'tip': 9066,
#  'make': 5489,
#  'sure': 8713,
#  'read': 7152,
#  'description': 2687,
#  'line': 5298,
#  'life': 5260,
#  'new': 6018,
#  'year': 9954,
#  'old': 6186,
#  'afraid': 566,
#  'loud': 5399,
#  'noises': 6050,
#  '12': 46,
#  'probably': 6888,
#  'major': 5486,
#  'overall': 6298,
#  'beautiful': 1137,
#  'wonderful': 9887,
#  'buy': 1530,
#  'teacup': 8856,
#  'standard': 8416,
#  'chinese': 1864,
#  'reasonable': 7171,
#  'adults': 529,
#  'roller': 7578,
#  'coasters': 2002,
#  'disappointed': 2815,
#  'flat': 3767,
#  'enjoyable': 3247,
#  'disneylands': 2874,
#  'region': 7267,
#  'sleeping': 8104,
#  'beauty': 1140,
#  'renovation': 7350,
#  'pictures': 6585,
#  'taken': 8804,
#  'square': 8377,
#  'appealing': 769,
#  'scaffolding': 7716,
#  'sight': 8016,
#  'donald': 2955,
#  'duck': 3066,
#  'photo': 6558,
#  'paid': 6361,
#  'available': 987,
#  'tomorrow': 9104,
#  'excellent': 3395,
#  'adventure': 536,
#  'opportunities': 6221,
#  'tarzan': 8831,
#  'boat': 1303,
#  'grizzly': 4225,
#  'gulch': 4265,
#  'favourites': 3644,
#  'coaster': 2001,
#  '15': 66,
#  'minute': 5768,
#  'generic': 4050,
#  'apart': 752,
#  'language': 5153,
#  'different': 2761,
#  'shame': 7916,
#  'trip': 9248,
#  'ago': 586,
#  'smallish': 8139,
#  'high': 4435,
#  'outdoor': 6275,
#  'clean': 1937,
#  'tidy': 9028,
#  'qualify': 7025,
#  'served': 7878,
#  'warm': 9701,
#  'cold': 2028,
#  'vegetarian': 9558,
#  'virtually': 9617,
#  'non': 6052,
#  'existent': 3438,
#  'entry': 3293,
#  'comparatively': 2102,
#  'inexpensive': 4779,
#  'times': 9052,
#  'chicken': 1846,
#  'try': 9276,
#  'visits': 9628,
#  'finally': 3716,
#  'courage': 2340,
#  'ended': 3222,
#  'loving': 5413,
#  'scary': 7735,
#  'opening': 6204,
#  'short': 7963,
#  'wanted': 9696,
#  'afternoon': 570,
#  'renovated': 7348,
#  'decided': 2585,
#  '8th': 363,
#  'kiddy': 5060,
#  'equates': 3304,
#  'aud': 952,
#  'bottle': 1355,
#  'burger': 1504,
#  'combo': 2058,
#  'meal': 5613,
#  '22': 164,
#  'stayed': 8458,
#  'hollywood': 4489,
#  'hotel': 4556,
#  'balls': 1061,
#  'charge': 1784,
#  'insane': 4819,
#  '120': 47,
#  'buffet': 1471,
#  'dinner': 2778,
#  '55': 288,
#  'breakfast': 1399,
#  'cafes': 1550,
#  'supermarkets': 8693,
#  'nearby': 5976,
#  'grab': 4155,
#  'snack': 8167,
#  'cheap': 1804,
#  'unless': 9413,
#  'travelling': 9220,
#  'china': 1863,
#  'weeks': 9784,
#  'crazy': 2386,
#  'crappy': 2379,
#  'deep': 2610,
#  'fried': 3937,
#  'bowl': 1370,
#  'lettuce': 5249,
#  'salad': 7658,
#  'vouchers': 9645,
#  'stating': 8449,
#  'st': 8386,
#  'discount': 2829,
#  '1030': 24,
#  'told': 9093,
#  'false': 3575,
#  'advertising': 544,
#  'toy': 9158,
#  'story': 8524,
#  'insanely': 4820,
#  'sun': 8672,
#  'bouncing': 1364,
#  'light': 5269,
#  'concrete': 2156,
#  'husband': 4608,
#  'actually': 483,
#  'coz': 2359,
#  'surely': 8714,
#  'shades': 7907,
#  'parents': 6405,
#  'elderly': 3158,
#  'wouldn': 9927,
#  '900': 368,
#  'poorer': 6712,
#  'note': 6075,
#  'fault': 3630,
#  'hire': 4455,
#  'pram': 6781,
#  'quickly': 7054,
#  'replaced': 7371,
#  'hotels': 4557,
#  'makes': 5493,
#  'easier': 3106,
#  'couple': 2335,
#  'selection': 7833,
#  'foods': 3837,
#  'caramel': 1627,
#  'bars': 1094,
#  'shopping': 7961,
#  'highlight': 4438,
#  'gifts': 4081,
#  'clothing': 1984,
#  'daily': 2500,
#  'special': 8292,
#  'sell': 7840,
#  'bring': 1426,
#  'hats': 4347,
#  'umbrella': 9333,
#  'trepidation': 9240,
#  'months': 5848,
#  'previously': 6849,
#  'needed': 5987,
#  'hkdl': 4468,
#  'yes': 9962,
#  'paced': 6344,
#  'large': 5161,
#  'amounts': 683,
#  'numbers': 6102,
#  'ups': 9469,
#  'held': 4402,
#  '3pm': 236,
#  'started': 8434,
#  'umbrellas': 9334,
#  'undercover': 9358,
#  'totally': 9133,
#  'mind': 5737,
#  'slower': 8127,
#  'hyperspace': 4623,
#  'car': 1625,
#  'shanghai': 7918,
#  'sea': 7785,
#  'walking': 9676,
#  'gates': 4027,
#  'owned': 6339,
#  'government': 4153,
#  'morning': 5855,
#  'things': 8963,
#  '10am': 28,
#  'storyland': 8526,
#  '11am': 43,
#  'purchased': 6995,
#  'australia': 967,
#  'printed': 6869,
#  'sent': 7859,
#  'email': 3180,
#  'link': 5306,
#  'electronic': 3164,
#  'version': 9581,
#  'qr': 7020,
#  'codes': 2016,
#  'personalised': 6529,
#  'used': 9488,
#  'website': 9769,
#  'dining': 2777,
#  'entitled': 3283,
#  'lunch': 5434,
#  'double': 2969,
#  'purchase': 6994,
#  'uses': 9493,
#  'scan': 7721,
#  'fastpass': 3618,
#  'staying': 8459,
#  'explorers': 3494,
#  'lodge': 5355,
#  'received': 7181,
#  'passes': 6441,
#  'aimed': 595,
#  'asian': 869,
#  'market': 5549,
#  'serve': 7877,
#  'burgers': 1505,
#  'fussy': 3990,
#  'eaters': 3119,
#  'beware': 1211,
#  'limited': 5293,
#  'quality': 7027,
#  'ate': 910,
#  'starliner': 8431,
#  'overlay': 6313,
#  'sooo': 8230,
#  'pirates': 6611,
#  'caribbean': 1643,
#  'sad': 7644,
#  'philharmagic': 6550,
#  'unique': 9402,
#  'mystic': 5930,
#  'manor': 5531,
#  'trackless': 9166,
#  'runaway': 7628,
#  'cars': 1667,
#  'varies': 9543,
#  'depending': 2674,
#  'sitting': 8073,
#  'rough': 7594,
#  'simulator': 8049,
#  'stark': 8430,
#  'flyer': 3813,
#  'remember': 7324,
#  'choose': 1877,
#  'english': 3243,
#  'cantonese': 1607,
#  'script': 7779,
#  'difference': 2759,
#  'allows': 647,
#  'break': 1395,
#  'net': 6014,
#  'speed': 8307,
#  'girls': 4088,
#  '17': 81,
#  'attended': 931,
#  'christmas': 1887,
#  'decorations': 2602,
#  'change': 1766,
#  'sunny': 8682,
#  'bay': 1117,
#  'use': 9487,
#  'octopus': 6157,
#  'card': 1630,
#  'travel': 9210,
#  'shuttle': 8003,
#  'buses': 1514,
#  'transport': 9201,
#  'hub': 4572,
#  'roughly': 7596,
#  'ferry': 3682,
#  'runs': 7634,
#  'option': 6234,
#  'shaped': 7920,
#  'windows': 9850,
#  'theming': 8953,
#  'carriages': 1656,
#  'australian': 968,
#  'chance': 1764,
#  'experiences': 3474,
#  'unexpected': 9381,
#  'rc': 7142,
#  'racer': 7072,
#  'toystoryland': 9162,
#  'families': 3579,
#  'younger': 9974,
#  'heaps': 4373,
#  'kind': 5068,
#  'skipped': 8093,
#  'fantasyland': 3599,
#  'simple': 8043,
#  'mong': 5826,
#  'discounted': 2830,
#  'rate': 7131,
#  'thai': 8930,
#  'bank': 1073,
#  'centre': 1739,
#  'road': 7550,
#  'right': 7527,
#  'kok': 5107,
#  'level': 5250,
#  'numerous': 6103,
#  'cts': 2447,
#  'reviews': 7501,
#  'asked': 874,
#  'cheapest': 1806,
#  'asking': 875,
#  'shop': 7958,
#  'sales': 7661,
#  'advisor': 551,
#  'hand': 4299,
#  'letter': 5246,
#  'box': 1373,
#  'office': 6169,
#  'swap': 8745,
#  'problems': 6891,
#  'opened': 6203,
#  'taxi': 8847,
#  'costs': 2312,
#  'route': 7602,
#  'pink': 6602,
#  'lai': 5133,
#  'orange': 6236,
#  'red': 7215,
#  'arriving': 850,
#  'heavily': 4392,
#  'stop': 8511,
#  'crowds': 2427,
#  'ghost': 4074,
#  'town': 9155,
#  'heard': 4375,
#  'favorite': 3640,
#  'usa': 9483,
#  'catering': 1700,
#  'mainly': 5476,
#  'happy': 4327,
#  'understand': 9367,
#  'brings': 1428,
#  'event': 3362,
#  'period': 6516,
#  'jan': 4956,
#  'feb': 3658,
#  'spring': 8368,
#  'carnival': 1647,
#  'summer': 8668,
#  'halloween': 4292,
#  'charaters': 1781,
#  'costume': 2313,
#  'decorate': 2598,
#  'thats': 8938,
#  'check': 1809,
#  'clearly': 1948,
#  'join': 4986,
#  'mar': 5539,
#  'november': 6094,
#  'happening': 4320,
#  'amusement': 688,
#  'tame': 8818,
#  'customer': 2480,
#  'maintained': 5480,
#  'priority': 6878,
#  'reminders': 7331,
#  'selfie': 7837,
#  'sticks': 8489,
#  'reusable': 7488,
#  'container': 2228,
#  'instead': 4841,
#  'rollercoasters': 7580,
#  'away': 1008,
#  'festival': 3684,
#  'production': 6906,
#  'songs': 8225,
#  'movie': 5889,
#  'wear': 9762,
#  'comfortable': 2065,
#  'shoes': 7953,
#  'discouraged': 2833,
#  'long': 5368,
#  'turn': 9300,
#  'sooner': 8229,
#  'honest': 4502,
#  'rained': 7093,
#  'nearly': 5980,
#  'weather': 9766,
#  'impression': 4700,
#  'lacks': 5126,
#  'seeking': 7824,
#  'lacked': 5122,
#  'ridiculously': 7524,
#  'waits': 9668,
#  'cute': 2485,
#  'tick': 9021,
#  'warned': 9708,
#  'translate': 9197,
#  'lucky': 5424,
#  'nugget': 6098,
#  'saloon': 7665,
#  'mediocre': 5633,
#  'plaza': 6660,
#  'inn': 4809,
#  'group': 4234,
#  'skip': 8092,
#  'disneyworld': 2878,
#  'orlando': 6264,
#  '40': 242,
#  'yrs': 9983,
#  'various': 9546,
#  'fee': 3661,
#  'covers': 2355,
#  'hasn': 4339,
#  'remarkably': 7321,
#  'given': 4089,
#  'till': 9041,
#  'later': 5175,
#  '5pm': 301,
#  '10minutes': 32,
#  '15pm': 75,
#  'exhausting': 3428,
#  'simply': 8047,
#  'saturday': 7696,
#  'sunday': 8677,
#  'opens': 6207,
#  '00': 0,
#  'zone': 9995,
#  'weekend': 9781,
#  'terrific': 8915,
#  'ok': 6182,
#  'friendly': 3942,
#  'set': 7890,
#  'adult': 527,
#  'bigger': 1219,
#  'worked': 9905,
#  'college': 2039,
#  'came': 1576,
#  'knew': 5089,
#  'paris': 6407,
#  'regret': 7274,
#  'smallest': 8138,
#  'liked': 5282,
#  'ranger': 7116,
#  'dressed': 3032,
#  'easter': 3110,
#  'night': 6039,
#  'reminded': 7329,
#  'pricey': 6855,
#  'somewhat': 8222,
#  'maximize': 5599,
#  'additional': 495,
#  'vip': 9615,
#  'status': 8456,
#  'heaven': 4388,
#  'downside': 2990,
#  'appears': 776,
#  'hard': 4330,
#  'variation': 9540,
#  'pop': 6715,
#  'corn': 2290,
#  'cob': 2005,
#  'outlets': 6284,
#  'selves': 7845,
#  '50': 274,
#  'friend': 3938,
#  'blew': 1272,
#  'filled': 3705,
#  'entertainment': 3271,
#  'halal': 4285,
#  'cater': 1698,
#  'needs': 5991,
#  'glad': 4092,
#  'meet': 5635,
#  'friends': 3943,
#  'fact': 3542,
#  'plus': 6676,
#  'facilities': 3539,
#  'loads': 5339,
#  'games': 4012,
#  'safe': 7649,
#  'mrt': 5894,
#  'transit': 9195,
#  'tram': 9184,
#  'impressive': 4702,
#  'teenage': 8874,
#  'sisters': 8068,
#  'offerings': 6167,
#  'albeit': 618,
#  'incredibly': 4749,
#  'catered': 1699,
#  'thrilling': 8994,
#  'maybe': 5605,
#  'western': 9800,
#  ...}

# %%
# are these numbers the count of each word? that would make sense.... but no
# we can see better what is going on if we sort by the values on the right

dict(sorted(vect.vocabulary_.items(), key=lambda x: x[1]))

# the above code is ugly, weird and unnecessary as python will do it for us like this
vect.get_feature_names()
# Out:
# ['00',
#  '000',
#  '00am',
#  '00pm',
#  '01',
#  '02',
#  '02m',
#  '03',
#  '04',
#  '05',
#  '06',
#  '07',
#  '08',
#  '0800',
#  '09',
#  '0900',
#  '10',
#  '100',
#  '1000',
#  '100hk',
#  '100hkd',
#  '101',
#  '102',
#  '102cm',
#  '1030',
#  '1030am',
#  '104',
#  '105',
#  '10am',
#  '10k',
#  '10min',
#  '10mins',
#  '10minutes',
#  '10pm',
#  '10th',
#  '10x',
#  '10years',
#  '10yrs',
#  '11',
#  '110',
#  '1100',
#  '112',
#  '115',
#  '11am',
#  '11pm',
#  '11th',
#  '12',
#  '120',
#  '1200',
#  '120cm',
#  '125',
#  '129',
#  '12am',
#  '12pm',
#  '12th',
#  '13',
#  '130',
#  '1300',
#  '135',
#  '137',
#  '139',
#  '13th',
#  '14',
#  '140',
#  '1400',
#  '14th',
#  '15',
#  '150',
#  '1500',
#  '155',
#  '15am',
#  '15euros',
#  '15min',
#  '15mins',
#  '15minutes',
#  '15pm',
#  '15th',
#  '16',
#  '160',
#  '1600',
#  '16th',
#  '17',
#  '170',
#  '1700',
#  '1730',
#  '175',
#  '17th',
#  '18',
#  '180',
#  '1800',
#  '18th',
#  '19',
#  '1930',
#  '1950',
#  '1950s',
#  '1955',
#  '1956',
#  '1957',
#  '1959',
#  '1960',
#  '1966',
#  '1967',
#  '1970',
#  '1977',
#  '1978',
#  '1979',
#  '1980',
#  '1980s',
#  '1984',
#  '1990',
#  '1991',
#  '1992',
#  '1993',
#  '1994',
#  '1995',
#  '1996',
#  '1997',
#  '1998',
#  '1999',
#  '19th',
#  '1am',
#  '1day',
#  '1h',
#  '1hour',
#  '1hr',
#  '1m',
#  '1pm',
#  '1st',
#  '1year',
#  '20',
#  '200',
#  '2000',
#  '2001',
#  '2002',
#  '2003',
#  '2004',
#  '2005',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '2010',
#  '2011',
#  '2012',
#  '2013',
#  '2014',
#  '2015',
#  '2016',
#  '2017',
#  '2018',
#  '2019',
#  '20am',
#  '20euros',
#  '20min',
#  '20mins',
#  '20minutes',
#  '20pm',
#  '20s',
#  '20th',
#  '20yrs',
#  '21',
#  '210',
#  '2100',
#  '21st',
#  '22',
#  '220',
#  '22nd',
#  '23',
#  '230',
#  '2300',
#  '23rd',
#  '24',
#  '240',
#  '24hrs',
#  '24th',
#  '25',
#  '250',
#  '25min',
#  '25mins',
#  '25th',
#  '26',
#  '26th',
#  '27',
#  '270',
#  '27th',
#  '28',
#  '280',
#  '28th',
#  '29',
#  '29th',
#  '2am',
#  '2day',
#  '2days',
#  '2hours',
#  '2hr',
#  '2hrs',
#  '2k',
#  '2m',
#  '2nd',
#  '2park',
#  '2pm',
#  '2x',
#  '2yr',
#  '2yrs',
#  '30',
#  '300',
#  '3000',
#  '30am',
#  '30ish',
#  '30min',
#  '30mins',
#  '30minutes',
#  '30pm',
#  '30s',
#  '30th',
#  '31',
#  '31st',
#  '32',
#  '320',
#  '33',
#  '330',
#  '34',
#  '35',
#  '350',
#  '35mins',
#  '36',
#  '360',
#  '365',
#  '37',
#  '38',
#  '39',
#  '399',
#  '3d',
#  '3day',
#  '3days',
#  '3hrs',
#  '3pm',
#  '3rd',
#  '3x',
#  '3yo',
#  '3yr',
#  '3yrs',
#  '40',
#  '400',
#  '40m',
#  '40min',
#  '40mins',
#  '40minutes',
#  '40pm',
#  '40s',
#  '40th',
#  '41',
#  '42',
#  '43',
#  '44',
#  '45',
#  '450',
#  '45am',
#  '45min',
#  '45mins',
#  '45minutes',
#  '45pm',
#  '46',
#  '460',
#  '47',
#  '48',
#  '49',
#  '499',
#  '4d',
#  '4pm',
#  '4th',
#  '4x',
#  '4yo',
#  '4yr',
#  '50',
#  '500',
#  '500ml',
#  '50euros',
#  '50mins',
#  '50pm',
#  '50s',
#  '50th',
#  '51',
#  '52',
#  '53',
#  '530',
#  '539',
#  '54',
#  '55',
#  '550',
#  '55pm',
#  '56',
#  '57',
#  '58',
#  '59',
#  '5d',
#  '5days',
#  '5hrs',
#  '5min',
#  '5mins',
#  '5minutes',
#  '5pm',
#  '5th',
#  '5yo',
#  '5yr',
#  '5yrs',
#  '60',
#  '600',
#  '60min',
#  '60mins',
#  '60s',
#  '60th',
#  '61',
#  '62',
#  '63',
#  '64',
#  '65',
#  '66',
#  '67',
#  '68',
#  '69',
#  '6am',
#  '6pm',
#  '6th',
#  '6year',
#  '6yo',
#  '6yr',
#  '70',
#  '700',
#  '70s',
#  '70th',
#  '71',
#  '72',
#  '73',
#  '730pm',
#  '74',
#  '75',
#  '75min',
#  '75mins',
#  '76',
#  '77',
#  '78',
#  '79',
#  '7am',
#  '7pm',
#  '7th',
#  '7yo',
#  '7yr',
#  '7yrs',
#  '80',
#  '800',
#  '80mins',
#  '80s',
#  '83',
#  '830',
#  '84',
#  '85',
#  '86',
#  '87',
#  '88',
#  '89',
#  '8am',
#  '8pm',
#  '8th',
#  '8yo',
#  '8yr',
#  '8yrs',
#  '90',
#  '900',
#  '90min',
#  '90mins',
#  '90s',
#  '92',
#  '93',
#  '930',
#  '94',
#  '95',
#  '96',
#  '97',
#  '98',
#  '99',
#  '9am',
#  '9pm',
#  '9th',
#  'a1',
#  'a4',
#  'aaa',
#  'aback',
#  'abandoned',
#  'abd',
#  'ability',
#  'abit',
#  'able',
#  'aboard',
#  'abound',
#  'abraham',
#  'abroad',
#  'abrupt',
#  'abruptly',
#  'absence',
#  'absent',
#  'absolute',
#  'absolutely',
#  'absolutley',
#  'absolutly',
#  'absorb',
#  'absurd',
#  'abt',
#  'abundance',
#  'abundant',
#  'abuse',
#  'abused',
#  'abysmal',
#  'ac',
#  'academy',
#  'accent',
#  'accents',
#  'accept',
#  'acceptable',
#  'accepted',
#  'accepting',
#  'accesible',
#  'access',
#  'accessed',
#  'accessibility',
#  'accessible',
#  'accessing',
#  'accessories',
#  'accident',
#  'accidentally',
#  'accidents',
#  'accommodate',
#  'accommodated',
#  'accommodates',
#  'accommodating',
#  'accommodation',
#  'accommodations',
#  'accomodate',
#  'accomodating',
#  'accomodation',
#  'accomodations',
#  'accompanied',
#  'accompany',
#  'accompanying',
#  'accomplish',
#  'accomplished',
#  'according',
#  'accordingly',
#  'account',
#  'accounts',
#  'accurate',
#  'accused',
#  'accustomed',
#  'ace',
#  'ache',
#  'achieve',
#  'achieved',
#  'achievement',
#  'aching',
#  'acknowledge',
#  'acknowledged',
#  'acknowledgement',
#  'acquainted',
#  'acquire',
#  'acquired',
#  'acre',
#  'acres',
#  'acrobatics',
#  'act',
#  'acted',
#  'acting',
#  'action',
#  'actions',
#  'active',
#  'actively',
#  'activites',
#  'activities',
#  'activity',
#  'actor',
#  'actors',
#  'actress',
#  'acts',
#  'actual',
#  'actually',
#  'ad',
#  'ada',
#  'adapt',
#  'adapted',
#  'add',
#  'added',
#  'addict',
#  'addicted',
#  'addictive',
#  'adding',
#  'addition',
#  'additional',
#  'additionally',
#  'additions',
#  'address',
#  'addressed',
#  'addressing',
#  'adds',
#  'adequate',
#  'adequately',
#  'adhd',
#  'adjacent',
#  'adjoining',
#  'adjust',
#  'adjusted',
#  'admiral',
#  'admire',
#  'admiring',
#  'admission',
#  'admissions',
#  'admit',
#  'admittance',
#  'admitted',
#  'admittedly',
#  'adopt',
#  'adorable',
#  'adore',
#  'adored',
#  'adores',
#  'adorned',
#  'adrenalin',
#  'adrenaline',
#  'ads',
#  'adult',
#  'adulthood',
#  'adults',
#  'adv',
#  'advance',
#  'advanced',
#  'advantage',
#  'advantages',
#  'adventur',
#  'adventure',
#  'adventureland',
#  'adventures',
#  'adventurous',
#  'advert',
#  'advertise',
#  'advertised',
#  'advertisement',
#  'advertising',
#  'adverts',
#  'advice',
#  'advisable',
#  'advise',
#  'advised',
#  'advising',
#  'advisor',
#  'aerial',
#  'aerosmith',
#  'afar',
#  'affair',
#  'affairs',
#  'affect',
#  'affected',
#  'affection',
#  'affects',
#  'affiliated',
#  'afford',
#  'affordable',
#  'aficionado',
#  'aforementioned',
#  'afraid',
#  'africa',
#  'african',
#  'afterall',
#  'afternoon',
#  'afternoons',
#  'afterward',
#  'ag',
#  'age',
#  'aged',
#  'ageing',
#  'agency',
#  'agenda',
#  'agent',
#  'agents',
#  'ages',
#  'aggravation',
#  'aggressive',
#  'agian',
#  'aging',
#  'ago',
#  'agrabah',
#  'agree',
#  'agreed',
#  'ah',
#  'ahead',
#  'aid',
#  'aids',
#  'aim',
#  'aimed',
#  'aiming',
#  'aimlessly',
#  'ain',
#  'air',
#  'aircon',
#  'airconditioned',
#  'airconditioning',
#  'airfare',
#  'airline',
#  'airlines',
#  'airplane',
#  'airport',
#  'airports',
#  'aisle',
#  'aisles',
#  'aka',
#  'akin',
#  'al',
#  'aladdin',
#  'aladin',
#  'alarm',
#  'alas',
#  'albeit',
#  'albert',
#  'album',
#  'alcohol',
#  'alcoholic',
#  'alert',
#  'alex',
#  'alice',
#  'aliens',
#  'alike',
#  'alive',
#  'alladin',
#  'allegedly',
#  'allergic',
#  'allergies',
#  'allergy',
#  'alleviate',
#  'alley',
#  'alll',
#  'allocate',
#  'allocated',
#  'allocation',
#  'allot',
#  'alloted',
#  'allotted',
#  'allow',
#  'allowance',
#  'allowed',
#  'allowing',
#  'allows',
#  'alongside',
#  'alot',
#  'aloud',
#  'alright',
#  'alter',
#  'alternate',
#  'alternating',
#  'alternative',
#  'alternatively',
#  'alternatives',
#  'altho',
#  'althought',
#  'altitude',
#  'altogether',
#  'alton',
#  'alway',
#  'amaz',
#  'amaze',
#  'amazed',
#  'amazement',
#  'amazes',
#  'amazing',
#  'amazingly',
#  'amazon',
#  'ambiance',
#  'ambience',
#  'ambulance',
#  'amd',
#  'amenities',
#  'america',
#  'american',
#  'americana',
#  'americans',
#  'americas',
#  'amiss',
#  'amounts',
#  'ample',
#  'amtrak',
#  'amuse',
#  'amused',
#  'amusement',
#  'amusements',
#  'amusing',
#  'ana',
#  'anaheim',
#  'anahiem',
#  'ancient',
#  'android',
#  'andy',
#  'aneheim',
#  'angel',
#  'angeles',
#  'angels',
#  'anger',
#  'angle',
#  'angles',
#  'angrily',
#  'angry',
#  'angus',
#  'animagic',
#  'animagique',
#  'animal',
#  'animals',
#  'animated',
#  'animation',
#  'animations',
#  'animatronic',
#  'animatronics',
#  'ankle',
#  'ankles',
#  'anna',
#  'annette',
#  'annettes',
#  'anniversary',
#  'announce',
#  'announced',
#  'announcement',
#  'announcements',
#  'announcing',
#  'annoy',
#  'annoyance',
#  'annoyed',
#  'annoying',
#  'annoyingly',
#  'annual',
#  'annually',
#  'ans',
#  'answer',
#  'answered',
#  'answering',
#  'answers',
#  'ant',
#  'anti',
#  'anticipate',
#  'anticipated',
#  'anticipating',
#  'anticipation',
#  'anxiety',
#  'anxious',
#  'anybody',
#  'anymore',
#  'anytime',
#  'anyways',
#  'ap',
#  'apart',
#  'apartment',
#  'aplenty',
#  'apologetic',
#  'apologies',
#  'apologise',
#  'apologised',
#  'apologize',
#  'apologized',
#  'apology',
#  'app',
#  'appalled',
#  'appalling',
#  'apparent',
#  'apparently',
#  'appeal',
#  'appealed',
#  'appealing',
#  'appeals',
#  'appear',
#  'appearance',
#  'appearances',
#  'appeared',
#  'appearing',
#  'appears',
#  'appetite',
#  'appetizer',
#  'appetizers',
#  'applause',
#  'apple',
#  'apples',
#  'applicable',
#  'application',
#  'applied',
#  'applies',
#  'apply',
#  'appointed',
#  'appointment',
#  'appointments',
#  'appreciate',
#  'appreciated',
#  'appreciating',
#  'appreciation',
#  'apprehensive',
#  'approach',
#  'approachable',
#  'approached',
#  'approaches',
#  'approaching',
#  'appropriate',
#  'appropriately',
#  'approve',
#  'approved',
#  'approx',
#  'approximate',
#  'approximately',
#  'apps',
#  'april',
#  'ar',
#  'arc',
#  'arcade',
#  'arcades',
#  'arch',
#  'architecture',
#  'ard',
#  'area',
#  'areas',
#  'aren',
#  'arena',
#  'arent',
#  'areosmith',
#  'ares',
#  'argue',
#  'argued',
#  'arguing',
#  'argument',
#  'arguments',
#  'arial',
#  'ariel',
#  'ariels',
#  'arizona',
#  'ark',
#  'arm',
#  'armageddon',
#  'armed',
#  'arms',
#  'army',
#  'arrange',
#  'arranged',
#  'arrangement',
#  'arrangements',
#  'arranging',
#  'array',
#  'arrival',
#  'arrivals',
#  'arrive',
#  'arrived',
#  'arrives',
#  'arriving',
#  'arrogance',
#  'arrogant',
#  'arround',
#  'art',
#  'arthur',
#  'artifacts',
#  'artificial',
#  'artistic',
#  'artists',
#  'arts',
#  'artwork',
#  'asap',
#  'asd',
#  'asda',
#  'ash',
#  'ashamed',
#  'ashford',
#  'asia',
#  'asian',
#  'asians',
#  'aside',
#  'asimo',
#  'ask',
#  'asked',
#  'asking',
#  'asks',
#  'asleep',
#  'aspect',
#  'aspects',
#  'assault',
#  'assessment',
#  'assigned',
#  'assist',
#  'assistance',
#  'assistant',
#  'assistants',
#  'assisted',
#  'assisting',
#  'associate',
#  'associated',
#  'assorted',
#  'assortment',
#  'assume',
#  'assumed',
#  'assuming',
#  'assure',
#  'assured',
#  'asterix',
#  'asthma',
#  'astonished',
#  'astonishing',
#  'astounded',
#  'astounding',
#  'astro',
#  'astroblaster',
#  'astroblasters',
#  'astronomical',
#  'astronomically',
#  'aswell',
#  'ate',
#  'atleast',
#  'atm',
#  'atmospher',
#  'atmosphere',
#  'atmospheric',
#  'atraction',
#  'atractions',
#  'atrocious',
#  'attached',
#  'attack',
#  'attacked',
#  'attacks',
#  'attempt',
#  'attempted',
#  'attempting',
#  'attempts',
#  'attend',
#  'attendance',
#  'attendant',
#  'attendants',
#  'attended',
#  'attendees',
#  'attending',
#  'attention',
#  'attentive',
#  'attire',
#  'attitude',
#  'attitudes',
#  'attract',
#  'attracted',
#  'attracting',
#  'attraction',
#  'attractions',
#  'attractiontix',
#  'attractive',
#  'attracts',
#  'attrations',
#  'au',
#  'auber',
#  'auberge',
#  'auchan',
#  'aud',
#  'audience',
#  'audiences',
#  'audio',
#  'auditorium',
#  'aug',
#  'august',
#  'aunt',
#  'aura',
#  'aurora',
#  'aus',
#  'aussie',
#  'aussies',
#  'aust',
#  'austin',
#  'australia',
#  'australian',
#  'australians',
#  'authentic',
#  'authenticity',
#  'authorities',
#  'authority',
#  'autism',
#  'autistic',
#  'auto',
#  'autograph',
#  'autographs',
#  'automated',
#  'automatic',
#  'automatically',
#  'autopia',
#  'autotopia',
#  'autumn',
#  'avail',
#  'availability',
#  'available',
#  'ave',
#  'avengers',
#  'avenue',
#  'average',
#  'averaged',
#  'averaging',
#  'avid',
#  'avoid',
#  'avoided',
#  'avoiding',
#  'avoids',
#  'await',
#  ...]

# %%
importance = np.argsort(np.asarray(count.sum(axis=0)).ravel())[::-1]
#count_feature_names = np.array(vect.get_feature_names())
#count_feature_names[importance[:n_top]]

importance
# Out:
# array([2870, 7521, 2872, ..., 2241, 6817, 4041], dtype=int32)

# %%
vect.get_feature_names()[999]
# Out:
# 'await'

# %%
count_feature_names = np.array(vect.get_feature_names())
#count_feature_names[importance[:n_top]]

count_feature_names
# Out:
# array(['00', '000', '00am', ..., 'zoo', 'zoom', 'zurg'], dtype='<U15')

# %%
count_feature_names[importance[:n_top]]
# Out:
# array(['disney', 'rides', 'disneyland', 'time', 'day', 'ride', 'just',
#        'great', 'food', 'kids', 'place', 'good', 'really', 'like',
#        'visit', 'went', 'people', 'long', 'fast', 'fun', 'parks', 'pass',
#        'wait', 'experience', 'times', 'days', 'did', 'parade', 'world',
#        'don', 'year', 'children', 'staff', 'characters', 'mountain',
#        'got', 'line', 'lines', 'paris', 'old', 'family', 'worth',
#        'fireworks', 'attractions', 'going', 'small', 'little', 'hotel',
#        'queues', 'best', 'lot', 'expensive', 'loved', 'trip', 'make',
#        'queue', 'minutes', 'didn', 'amazing', 'love', 'better', 'way',
#        'magic', 'big', 'early', 'closed', 'hours', 'california',
#        'visited', 'magical', 'years', 'want', 'enjoyed', 'enjoy', 'hour',
#        'night', 'tickets', '10', 'space', 'need', 'sure', 'waiting',
#        'think', 'main', 'say', 'shows', 'recommend', 'nice', 'mickey',
#        'busy', 'bit', 'new', 'come', 'money', 'took', 'lots', 'things',
#        'use', 'ticket', 'crowded', 'crowds', 'train', 'quite', 'land',
#        'passes', 'adventure', '30', 'florida', 've', 'clean', 'theme',
#        'definitely', 'castle', 'thing', 'stay', 'walk', 'able', 'spent',
#        'know', 'hong', 'kong', 'daughter', 'adults', 'open', 'having',
#        'different', 'parades', 'especially', 'water', 'end', 'friendly',
#        'feel', 'plan', 'young', 'getting', 'fantastic', 'restaurants',
#        'street', 'try', 'wonderful', 'right', 'bad', 'walking', 'wanted',
#        'eat', 'christmas', 'service', 'spend', 'half', 'disappointed',
#        'buy', 'overall', 'star', 'smaller', 'pirates', 'bring', 'stayed',
#        'fastpass', 'happy', 'meet', 'child', 'area', 'price', 'cast',
#        '20', 'expect', 'wasn', 'week', 'ones', 'said', 'saw', 'weather',
#        'pretty', 'hot', 'thunder', 'shops', 'prices', 'thought', 'lunch',
#        'holiday', 'attraction', 'easy', 'hk', 'evening', 'plenty',
#        'visiting', 'special', 'used', 'away', 'places', 'expected', 'son',
#        'morning', '15', 'left', 'll', 'members', 'entrance', 'free',
#        'studios', 'helpful', 'jones', 'character', 'walt', 'let', 'huge',
#        'miss', 'felt', 'yes', 'indiana', 'couple', 'short', 'second',
#        'inside', 'told', 'minute', 'awesome', 'orlando', 'check', 'came',
#        'look', 'mins', 'cost', 'restaurant', 'earth', 'actually',
#        'season', 'watch', 'avoid', 'probably', 'light', 'return', 'ages',
#        'kid', 'extra', 'start', 'pay', 'book', 'beautiful', 'far', 'meal',
#        'high', 'does', 'available', 'close', 'happiest', 'outside',
#        'later', 'absolutely', 'waited', 'popular', 'queuing', 'save',
#        'excellent', 'course', 'halloween', 'age', 'drinks', 'areas',
#        'french', 'haunted', 'breakfast', 'favorite', 'seen', 'help',
#        'prepared', 'arrived', 'break', 'leave', 'buzz', 'looking',
#        'truly', 'coaster', 'longer', 'lovely', 'couldn', 'taking',
#        'photo', 'princess', 'caribbean', 'summer', 'drink', 'staying',
#        'ok', 'late', 'managed', 'maybe', 'photos', '45', 'work',
#        'husband', 'crowd', 'rest', 'bought', 'mouse', 'hotels', 'near',
#        'weekend', 'euros', 'room', 'single', 'station', 'birthday',
#        'compared', 'dinner', 'rude', 'perfect', 'afternoon', 'decided',
#        'twice', 'app', 'snacks', 'plus', 'quality', 'hopper', 'adult',
#        'hard', 'story', 'anaheim', 'home', 'highly', 'parking', 'sit',
#        'ago', 'number', 'point', 'stand', 'makes', 'missed', 'doesn',
#        'run', 'real', 'cars', 'weren', 'roller', 'mansion', 'life',
#        'wife', 'won', 'seeing', 'person', 'atmosphere', 'remember',
#        'spot', 'favourite', 'cold', '00', '11', '12', 'peter', 'booked',
#        'original', '40', 'disneyworld', 'options', 'princesses',
#        'possible', 'soon', 'brilliant', 'disappointing', 'past', 'wars',
#        'doing', 'pan', 'live', 'tired', 'extremely', 'isn', 'resort',
#        'allowed', 'stop', 'visitors', 'school', 'guests', 'older', 'paid',
#        'smoking', 'packed', 'entire', 'splash', 'tours', 'enter',
#        'started', 'opened', 'given', '50', 'friends', 'entry', 'security',
#        'taken', 'car', 'english', 'enjoyable', 'coming', 'pictures',
#        'offer', 'toy', 'super', 'bus', 'holidays', 'opening', 'fact',
#        'walked', 'view', 'needs', 'king', 'instead', 'problem', 'large',
#        'families', 'value', 'cool', 'memories', 'trying', 'dreams',
#        'access', 'wish', 'spectacular', 'euro', 'wouldn', 'poor',
#        'planning', 'gets', '60', 'usa', 'standing', 'village', 'minnie',
#        'average', 'mtr', 'straight', 'mind', 'online', 'set', 'kingdom',
#        'party', 'parents', 'pm', 'including', 'younger', 'member', 'gone',
#        'fan', 'min', 'easily', 'lightyear', 'tip', 'rain', 'forget',
#        'overpriced', 'fantasyland', 'review', 'tried', 'lion', 'display',
#        'unfortunately', 'cafe', 'option', 'dont', 'despite', 'cheaper',
#        'closing', 'usually', 'making', 'liked', 'ate', 'using', 'true',
#        'understand', 'kept', 'head', 'advance', 'asked', 'finally',
#        'shop', 'surprised', 'annual', 'looked', 'dream', 'choice',
#        'priced', 'gave', 'excited', 'working', 'matterhorn', 'firework',
#        'glad', 'kind', 'wrong', 'shopping', 'needed', 'advantage',
#        'blast', 'pricey', 'toilets', 'quickly', 'travel', 'manor',
#        'limited', 'tour', 'believe', 'totally', 'peak', 'unless', 'group',
#        'cheap', 'ask', 'longest', 'vacation', 'meals', 'suggest',
#        'watching', 'size', 'major', 'wdw', 'la', 'stuff', 'lack',
#        'themed', 'gates', 'anniversary', 'house', 'customer', 'matter',
#        'simply', 'reviews', 'idea', 'disappointment', 'waste', 'city',
#        'broke', 'thrill', 'takes', 'brought', 'eating', 'certainly',
#        'round', 'map', 'gate', 'tell', 'tower', 'grizzly', 'lucky',
#        'ahead', 'whilst', 'read', 'tips', 'quick', 'arrive', '90',
#        'reason', 'shuttle', 'queued', 'chance', 'music', 'snow', 'till',
#        'ended', 'mid', 'knew', 'site', 'nearly', 'entertainment', 'order',
#        'ice', 'shut', 'picture', 'hand', 'fantasy', 'studio', 'deal',
#        'crazy', 'downtown', 'fantasmic', 'fine', 'stroller', 'change',
#        'feeling', 'waits', 'certain', 'choose', 'running', 'meant',
#        'childhood', 'employees', '25', 'advice', 'nights', 'shorter',
#        'usual', 'souvenirs', 'forward', 'returned', 'care', 'exciting',
#        'works', 'rode', 'goes', 'cruise', 'american', 'mystic', 'bigger',
#        'hit', 'met', 'compare', 'monday', 'opens', 'lost', 'merchandise',
#        'oh', '100', 'attention', 'maintenance', 'girls', 'track',
#        'expectations', 'meeting', 'decorations', 'moment', 'man', 'heat',
#        'called', 'jungle', 'similar', 'hope', 'face', '10am', 'allow',
#        'highlight', 'worked', 'terror', 'aren', 'completely', 'ca',
#        'guess', 'fabulous', 'hollywood', 'included', 'bag', 'reasonable',
#        'beauty', 'note', 'earlier', 'board', 'cover', 'lights', 'changed',
#        'shoes', 'purchase', 'saturday', 'friday', 'paying', 'spending',
#        'website', 'ready', 'tea', 'dining', 'buffet', 'quiet', 'slow',
#        'august', 'smile', 'sunday', 'difficult', 'purchased', 'expecting',
#        'universal', 'baby', 'ridiculous', 'wear', 'bottle', 'frozen',
#        'saying', 'france', 'bags', 'sun', 'experienced', 'tomorrowland',
#        'version', 'worst', 'problems', 'loads', 'pick', 'dumbo',
#        'comfortable', 'obviously', 'non', 'phone', 'chinese', 'aged',
#        'strollers', 'broken', 'table', 'months', 'general', 'impressed',
#        'pushing', 'incredible', 'wow', 'complete', 'scary', 'dlp',
#        'planned', 'spring', 'public', 'amusement', 'issue', 'grand',
#        'list', 'blue', 'tokyo', 'sleeping', 'coffee', 'dark', 'boys',
#        'october', 'pooh', 'case', 'girl', 'looks', 'easier', 'low',
#        'july', 'opinion', 'turn', 'means', 'noticed', 'skip', 'admission',
#        'treat', 'biggest', 'heart', 'weekday', 'hardly', 'daughters',
#        'watched', 'shame', 'variety', 'white', 'difference', 'turned',
#        'cream', 'hall', 'various', 'rider', 'leaving', 'dl', 'heard',
#        'recommended', 'play', 'refurbishment', 'town', 'fastpasses',
#        '30pm', 'pleasant', 'month', 'buying', 'total', 'weekends', 'card',
#        'bottles', 'boat', 'cut', 'apart', 'generally', 'literally',
#        'example', 'middle', 'sad', 'haven', 'job', 'mean', 'visits',
#        'airport', 'interesting', 'didnt', 'massive', 'warm',
#        'particularly', 'starts', 'surprise', 'saved', 'standard',
#        'disabled', 'decent', 'imagine', 'bay', 'experiences', 'railroad',
#        'thank', 'considering', 'guest', 'friend', 'slightly', 'catch',
#        'normal', '13', 'seats', 'activities', 'ratatouille', 'costs',
#        'comes', 'terrible', 'goofy', 'store', 'multiple', 'que',
#        'december', 'information', 'paint', 'river', 'flight', 'bother',
#        'push', 'facilities', 'fans', 'technical', 'opportunity', 'issues',
#        'negative', 'fountains', 'maintained', 'fair', 'add', 'items',
#        'speak', 'awful', 'sunny', 'europe', 'pre', 'adventureland',
#        'booking', 'basically', 'helped', 'filled', 'local', 'hyperspace',
#        'thoroughly', 'missing', 'unique', 'location', '14', 'aware',
#        'max', 'nemo', 'uk', 'january', 'faces', 'burger', 'event',
#        'finding', 'package', 'comparison', 'classic', 'stopped', 'guide',
#        'offered', 'moving', 'smoke', 'pizza', 'recently', 'feet', 'rush',
#        'chicken', 'seat', 'pack', 'movie', 'vouchers', 'happened',
#        'consider', 'june', 'ocean', 'boy', 'chips', 'worse', '2nd',
#        'teenagers', 'riding', 'drop', 'winnie', 'gives', '1st', 'stood',
#        'reservations', 'manage', 'mor', 'september', 'america',
#        'travelling', 'parts', 'thinking', 'added', 'march', 'grown',
#        'frontierland', 'snack', 'winter', 'sign', 'honestly', 'stores',
#        'budget', 'prior', 'hongkong', 'lands', 'enjoying', 'wheelchair',
#        'alot', 'carry', 'exit', 'stars', 'previous', 'eyes', 'color',
#        'travelled', '70', 'control', 'charge', 'safe', 'notice', 'crush',
#        'tuesday', 'rooms', 'headed', 'door', 'thursday', 'wet', 'plaza',
#        'autopia', 'choices', 'research', 'sorry', 'ups', 'gift', 'golden',
#        'regular', 'air', 'wild', 'dirty', 'greet', 'seating', 'lifetime',
#        'gulch', 'excitement', 'cute', 'sell', 'offers', 'ques', 'type',
#        'grab', 'signs', 'level', 'suitable', 'november', 'downside',
#        'fairly', 'polite', '3rd', 'decorated', 'disappoint', 'organised',
#        'happen', 'sort', 'points', 'future', 'memorable', 'alice', 'sat',
#        'impossible', 'advise', 'laser', 'fault', 'cinderella',
#        'nightmare', 'management', 'based', 'entering', 'april',
#        'schedule', 'closes', '80', 'drive', 'mainly', 'discount', 'chose',
#        'tram', 'download', 'style', 'coasters', 'important', 'returning',
#        'complaint', 'unlike', 'bored', 'grandchildren', 'explore',
#        'sitting', 'dog', 'outlets', 'details', 'thrilling'], dtype='<U15')

# %%
np.asarray(count.sum(axis=0)).ravel()[importance[:n_top]]

name_count = dict(zip(count_feature_names[importance[:n_top]], np.asarray(count.sum(axis=0)).ravel()[importance[:n_top]]))

# %%
#Ta-da!

name_count
# Out:
# {'disney': 37139,
#  'rides': 34956,
#  'disneyland': 33569,
#  'time': 29824,
#  'day': 28923,
#  'ride': 18038,
#  'just': 16682,
#  'great': 16635,
#  'food': 14819,
#  'kids': 14359,
#  'place': 13564,
#  'good': 13360,
#  'really': 12436,
#  'like': 11994,
#  'visit': 11930,
#  'went': 11381,
#  'people': 11180,
#  'long': 10373,
#  'fast': 10146,
#  'fun': 10127,
#  'parks': 10050,
#  'pass': 9904,
#  'wait': 9840,
#  'experience': 9047,
#  'times': 8997,
#  'days': 8843,
#  'did': 8662,
#  'parade': 8581,
#  'world': 8212,
#  'don': 8187,
#  'year': 8174,
#  'children': 8099,
#  'staff': 8027,
#  'characters': 7846,
#  'mountain': 7683,
#  'got': 7383,
#  'line': 7316,
#  'lines': 7236,
#  'paris': 7197,
#  'old': 7039,
#  'family': 7025,
#  'worth': 7013,
#  'fireworks': 6913,
#  'attractions': 6908,
#  'going': 6877,
#  'small': 6851,
#  'little': 6828,
#  'hotel': 6738,
#  'queues': 6594,
#  'best': 6585,
#  'lot': 6580,
#  'expensive': 6500,
#  'loved': 6496,
#  'trip': 6433,
#  'make': 6415,
#  'queue': 6319,
#  'minutes': 6223,
#  'didn': 6101,
#  'amazing': 6076,
#  'love': 5989,
#  'better': 5868,
#  'way': 5771,
#  'magic': 5698,
#  'big': 5629,
#  'early': 5585,
#  'closed': 5367,
#  'hours': 5297,
#  'california': 5285,
#  'visited': 5281,
#  'magical': 5248,
#  'years': 5217,
#  'want': 5067,
#  'enjoyed': 4985,
#  'enjoy': 4904,
#  'hour': 4895,
#  'night': 4874,
#  'tickets': 4871,
#  '10': 4850,
#  'space': 4781,
#  'need': 4742,
#  'sure': 4741,
#  'waiting': 4720,
#  'think': 4663,
#  'main': 4652,
#  'say': 4483,
#  'shows': 4479,
#  'recommend': 4422,
#  'nice': 4375,
#  'mickey': 4311,
#  'busy': 4300,
#  'bit': 4200,
#  'new': 4183,
#  'come': 4163,
#  'money': 4150,
#  'took': 4148,
#  'lots': 4123,
#  'things': 4113,
#  'use': 4044,
#  'ticket': 4036,
#  'crowded': 4001,
#  'crowds': 3935,
#  'train': 3851,
#  'quite': 3838,
#  'land': 3828,
#  'passes': 3825,
#  'adventure': 3807,
#  '30': 3802,
#  'florida': 3797,
#  've': 3767,
#  'clean': 3595,
#  'theme': 3586,
#  'definitely': 3584,
#  'castle': 3562,
#  'thing': 3538,
#  'stay': 3528,
#  'walk': 3526,
#  'able': 3510,
#  'spent': 3411,
#  'know': 3407,
#  'hong': 3350,
#  'kong': 3340,
#  'daughter': 3324,
#  'adults': 3321,
#  'open': 3287,
#  'having': 3286,
#  'different': 3282,
#  'parades': 3260,
#  'especially': 3242,
#  'water': 3226,
#  'end': 3223,
#  'friendly': 3209,
#  'feel': 3180,
#  'plan': 3089,
#  'young': 3045,
#  'getting': 3019,
#  'fantastic': 3018,
#  'restaurants': 2989,
#  'street': 2988,
#  'try': 2952,
#  'wonderful': 2944,
#  'right': 2916,
#  'bad': 2884,
#  'walking': 2843,
#  'wanted': 2843,
#  'eat': 2826,
#  'christmas': 2807,
#  'service': 2794,
#  'spend': 2781,
#  'half': 2748,
#  'disappointed': 2707,
#  'buy': 2689,
#  'overall': 2687,
#  'star': 2679,
#  'smaller': 2679,
#  'pirates': 2670,
#  'bring': 2654,
#  'stayed': 2635,
#  'fastpass': 2622,
#  'happy': 2616,
#  'meet': 2609,
#  'child': 2602,
#  'area': 2595,
#  'price': 2590,
#  'cast': 2560,
#  '20': 2553,
#  'expect': 2544,
#  'wasn': 2495,
#  'week': 2490,
#  'ones': 2488,
#  'said': 2463,
#  'saw': 2419,
#  'weather': 2415,
#  'pretty': 2397,
#  'hot': 2386,
#  'thunder': 2382,
#  'shops': 2366,
#  'prices': 2366,
#  'thought': 2354,
#  'lunch': 2352,
#  'holiday': 2345,
#  'attraction': 2342,
#  'easy': 2338,
#  'hk': 2319,
#  'evening': 2305,
#  'plenty': 2302,
#  'visiting': 2281,
#  'special': 2277,
#  'used': 2254,
#  'away': 2250,
#  'places': 2248,
#  'expected': 2246,
#  'son': 2243,
#  'morning': 2235,
#  '15': 2225,
#  'left': 2218,
#  'll': 2208,
#  'members': 2207,
#  'entrance': 2204,
#  'free': 2197,
#  'studios': 2185,
#  'helpful': 2175,
#  'jones': 2163,
#  'character': 2147,
#  'walt': 2140,
#  'let': 2138,
#  'huge': 2127,
#  'miss': 2127,
#  'felt': 2111,
#  'yes': 2111,
#  'indiana': 2080,
#  'couple': 2080,
#  'short': 2071,
#  'second': 2068,
#  'inside': 2063,
#  'told': 2053,
#  'minute': 2047,
#  'awesome': 2046,
#  'orlando': 2044,
#  'check': 2019,
#  'came': 2006,
#  'look': 2005,
#  'mins': 1998,
#  'cost': 1992,
#  'restaurant': 1988,
#  'earth': 1973,
#  'actually': 1946,
#  'season': 1943,
#  'watch': 1934,
#  'avoid': 1930,
#  'probably': 1923,
#  'light': 1922,
#  'return': 1915,
#  'ages': 1911,
#  'kid': 1910,
#  'extra': 1907,
#  'start': 1896,
#  'pay': 1885,
#  'book': 1883,
#  'beautiful': 1878,
#  'far': 1857,
#  'meal': 1853,
#  'high': 1848,
#  'does': 1838,
#  'available': 1825,
#  'close': 1814,
#  'happiest': 1803,
#  'outside': 1803,
#  'later': 1798,
#  'absolutely': 1784,
#  'waited': 1771,
#  'popular': 1768,
#  'queuing': 1768,
#  'save': 1741,
#  'excellent': 1735,
#  'course': 1714,
#  'halloween': 1704,
#  'age': 1700,
#  'drinks': 1695,
#  'areas': 1678,
#  'french': 1672,
#  'haunted': 1665,
#  'breakfast': 1662,
#  'favorite': 1660,
#  'seen': 1656,
#  'help': 1656,
#  'prepared': 1649,
#  'arrived': 1627,
#  'break': 1627,
#  'leave': 1620,
#  'buzz': 1616,
#  'looking': 1615,
#  'truly': 1591,
#  'coaster': 1589,
#  'longer': 1587,
#  'lovely': 1586,
#  'couldn': 1586,
#  'taking': 1580,
#  'photo': 1578,
#  'princess': 1577,
#  'caribbean': 1566,
#  'summer': 1562,
#  'drink': 1559,
#  'staying': 1545,
#  'ok': 1538,
#  'late': 1537,
#  'managed': 1534,
#  'maybe': 1522,
#  'photos': 1512,
#  '45': 1508,
#  'work': 1504,
#  'husband': 1495,
#  'crowd': 1490,
#  'rest': 1488,
#  'bought': 1484,
#  'mouse': 1478,
#  'hotels': 1472,
#  'near': 1453,
#  'weekend': 1442,
#  'euros': 1441,
#  'room': 1441,
#  'single': 1439,
#  'station': 1435,
#  'birthday': 1434,
#  'compared': 1434,
#  'dinner': 1434,
#  'rude': 1433,
#  'perfect': 1428,
#  'afternoon': 1424,
#  'decided': 1421,
#  'twice': 1413,
#  'app': 1403,
#  'snacks': 1390,
#  'plus': 1388,
#  'quality': 1388,
#  'hopper': 1387,
#  'adult': 1387,
#  'hard': 1378,
#  'story': 1366,
#  'anaheim': 1365,
#  'home': 1364,
#  'highly': 1357,
#  'parking': 1357,
#  'sit': 1356,
#  'ago': 1349,
#  'number': 1347,
#  'point': 1346,
#  'stand': 1343,
#  'makes': 1341,
#  'missed': 1341,
#  'doesn': 1338,
#  'run': 1337,
#  'real': 1335,
#  'cars': 1334,
#  'weren': 1332,
#  'roller': 1332,
#  'mansion': 1330,
#  'life': 1327,
#  'wife': 1323,
#  'won': 1311,
#  'seeing': 1310,
#  'person': 1310,
#  'atmosphere': 1306,
#  'remember': 1297,
#  'spot': 1288,
#  'favourite': 1285,
#  'cold': 1285,
#  '00': 1280,
#  '11': 1279,
#  '12': 1279,
#  'peter': 1272,
#  'booked': 1271,
#  'original': 1250,
#  '40': 1250,
#  'disneyworld': 1247,
#  'options': 1246,
#  'princesses': 1245,
#  'possible': 1232,
#  'soon': 1226,
#  'brilliant': 1221,
#  'disappointing': 1218,
#  'past': 1216,
#  'wars': 1213,
#  'doing': 1213,
#  'pan': 1210,
#  'live': 1207,
#  'tired': 1207,
#  'extremely': 1206,
#  'isn': 1206,
#  'resort': 1204,
#  'allowed': 1197,
#  'stop': 1192,
#  'visitors': 1190,
#  'school': 1189,
#  'guests': 1187,
#  'older': 1182,
#  'paid': 1179,
#  'smoking': 1175,
#  'packed': 1171,
#  'entire': 1170,
#  'splash': 1165,
#  'tours': 1163,
#  'enter': 1162,
#  'started': 1162,
#  'opened': 1161,
#  'given': 1161,
#  '50': 1155,
#  'friends': 1150,
#  'entry': 1150,
#  'security': 1143,
#  'taken': 1142,
#  'car': 1141,
#  'english': 1140,
#  'enjoyable': 1140,
#  'coming': 1139,
#  'pictures': 1131,
#  'offer': 1129,
#  'toy': 1127,
#  'super': 1126,
#  'bus': 1126,
#  'holidays': 1122,
#  'opening': 1117,
#  'fact': 1116,
#  'walked': 1113,
#  'view': 1111,
#  'needs': 1111,
#  'king': 1110,
#  'instead': 1108,
#  'problem': 1099,
#  'large': 1098,
#  'families': 1096,
#  'value': 1094,
#  'cool': 1093,
#  'memories': 1090,
#  'trying': 1088,
#  'dreams': 1087,
#  'access': 1085,
#  'wish': 1083,
#  'spectacular': 1079,
#  'euro': 1078,
#  'wouldn': 1074,
#  'poor': 1074,
#  'planning': 1068,
#  'gets': 1066,
#  '60': 1065,
#  'usa': 1061,
#  'standing': 1058,
#  'village': 1057,
#  'minnie': 1056,
#  'average': 1054,
#  'mtr': 1054,
#  'straight': 1047,
#  'mind': 1040,
#  'online': 1040,
#  'set': 1037,
#  'kingdom': 1036,
#  'party': 1035,
#  'parents': 1034,
#  'pm': 1034,
#  'including': 1034,
#  'younger': 1033,
#  'member': 1033,
#  'gone': 1030,
#  'fan': 1028,
#  'min': 1027,
#  'easily': 1024,
#  'lightyear': 1023,
#  'tip': 1015,
#  'rain': 1005,
#  'forget': 1005,
#  'overpriced': 1005,
#  'fantasyland': 1005,
#  'review': 1004,
#  'tried': 1002,
#  'lion': 1001,
#  'display': 1000,
#  'unfortunately': 999,
#  'cafe': 996,
#  'option': 996,
#  'dont': 993,
#  'despite': 993,
#  'cheaper': 990,
#  'closing': 990,
#  'usually': 989,
#  'making': 985,
#  'liked': 984,
#  'ate': 980,
#  'using': 972,
#  'true': 962,
#  'understand': 957,
#  'kept': 956,
#  'head': 955,
#  'advance': 955,
#  'asked': 954,
#  'finally': 953,
#  'shop': 950,
#  'surprised': 949,
#  'annual': 946,
#  'looked': 942,
#  'dream': 937,
#  'choice': 937,
#  'priced': 934,
#  'gave': 934,
#  'excited': 933,
#  'working': 933,
#  'matterhorn': 933,
#  'firework': 932,
#  'glad': 931,
#  'kind': 928,
#  'wrong': 926,
#  'shopping': 924,
#  'needed': 924,
#  'advantage': 923,
#  'blast': 923,
#  'pricey': 919,
#  'toilets': 919,
#  'quickly': 919,
#  'travel': 918,
#  'manor': 918,
#  'limited': 916,
#  'tour': 911,
#  'believe': 911,
#  'totally': 909,
#  'peak': 909,
#  'unless': 907,
#  'group': 902,
#  'cheap': 901,
#  'ask': 901,
#  'longest': 899,
#  'vacation': 898,
#  'meals': 896,
#  'suggest': 895,
#  'watching': 895,
#  'size': 894,
#  'major': 892,
#  'wdw': 892,
#  'la': 891,
#  'stuff': 889,
#  'lack': 888,
#  'themed': 886,
#  'gates': 882,
#  'anniversary': 880,
#  'house': 878,
#  'customer': 878,
#  'matter': 876,
#  'simply': 875,
#  'reviews': 874,
#  'idea': 871,
#  'disappointment': 869,
#  'waste': 866,
#  'city': 865,
#  'broke': 862,
#  'thrill': 860,
#  'takes': 860,
#  'brought': 858,
#  'eating': 855,
#  'certainly': 854,
#  'round': 848,
#  'map': 847,
#  'gate': 847,
#  'tell': 846,
#  'tower': 844,
#  'grizzly': 841,
#  'lucky': 834,
#  'ahead': 829,
#  'whilst': 825,
#  'read': 823,
#  'tips': 823,
#  'quick': 819,
#  'arrive': 818,
#  '90': 816,
#  'reason': 815,
#  'shuttle': 814,
#  'queued': 812,
#  'chance': 811,
#  'music': 810,
#  'snow': 808,
#  'till': 805,
#  'ended': 803,
#  'mid': 802,
#  'knew': 799,
#  'site': 798,
#  'nearly': 798,
#  'entertainment': 792,
#  'order': 792,
#  'ice': 791,
#  'shut': 787,
#  'picture': 787,
#  'hand': 784,
#  'fantasy': 784,
#  'studio': 783,
#  'deal': 782,
#  'crazy': 781,
#  'downtown': 775,
#  'fantasmic': 772,
#  'fine': 771,
#  'stroller': 768,
#  'change': 766,
#  'feeling': 766,
#  'waits': 765,
#  'certain': 756,
#  'choose': 753,
#  'running': 752,
#  'meant': 751,
#  'childhood': 746,
#  'employees': 745,
#  '25': 744,
#  'advice': 743,
#  'nights': 741,
#  'shorter': 739,
#  'usual': 739,
#  'souvenirs': 739,
#  'forward': 737,
#  'returned': 737,
#  'care': 737,
#  'exciting': 736,
#  'works': 733,
#  'rode': 732,
#  'goes': 731,
#  'cruise': 729,
#  'american': 727,
#  'mystic': 724,
#  'bigger': 723,
#  'hit': 719,
#  'met': 718,
#  'compare': 718,
#  'monday': 714,
#  'opens': 712,
#  'lost': 711,
#  'merchandise': 710,
#  'oh': 710,
#  '100': 709,
#  'attention': 708,
#  'maintenance': 707,
#  'girls': 706,
#  'track': 704,
#  'expectations': 703,
#  'meeting': 703,
#  'decorations': 702,
#  'moment': 701,
#  'man': 700,
#  'heat': 700,
#  'called': 697,
#  'jungle': 696,
#  'similar': 695,
#  'hope': 692,
#  'face': 692,
#  '10am': 690,
#  'allow': 688,
#  'highlight': 686,
#  'worked': 682,
#  'terror': 681,
#  'aren': 678,
#  'completely': 674,
#  'ca': 673,
#  'guess': 673,
#  'fabulous': 672,
#  'hollywood': 672,
#  'included': 671,
#  'bag': 670,
#  'reasonable': 670,
#  'beauty': 669,
#  'note': 668,
#  'earlier': 666,
#  'board': 666,
#  'cover': 665,
#  'lights': 664,
#  'changed': 662,
#  'shoes': 662,
#  'purchase': 661,
#  'saturday': 660,
#  'friday': 659,
#  'paying': 657,
#  'spending': 657,
#  'website': 655,
#  'ready': 654,
#  'tea': 654,
#  'dining': 654,
#  'buffet': 654,
#  'quiet': 653,
#  'slow': 653,
#  'august': 651,
#  'smile': 651,
#  'sunday': 651,
#  'difficult': 650,
#  'purchased': 648,
#  'expecting': 648,
#  'universal': 648,
#  'baby': 646,
#  'ridiculous': 645,
#  'wear': 643,
#  'bottle': 643,
#  'frozen': 642,
#  'saying': 641,
#  'france': 640,
#  'bags': 639,
#  'sun': 639,
#  'experienced': 638,
#  'tomorrowland': 637,
#  'version': 635,
#  'worst': 633,
#  'problems': 632,
#  'loads': 632,
#  'pick': 630,
#  'dumbo': 629,
#  'comfortable': 625,
#  'obviously': 624,
#  'non': 623,
#  'phone': 622,
#  'chinese': 622,
#  'aged': 621,
#  'strollers': 620,
#  'broken': 618,
#  'table': 617,
#  'months': 617,
#  'general': 614,
#  'impressed': 614,
#  'pushing': 613,
#  'incredible': 613,
#  'wow': 612,
#  'complete': 611,
#  'scary': 609,
#  'dlp': 609,
#  'planned': 609,
#  'spring': 608,
#  'public': 606,
#  'amusement': 605,
#  'issue': 605,
#  'grand': 604,
#  'list': 604,
#  'blue': 599,
#  'tokyo': 599,
#  'sleeping': 598,
#  'coffee': 596,
#  'dark': 596,
#  'boys': 596,
#  'october': 595,
#  'pooh': 593,
#  'case': 593,
#  'girl': 592,
#  'looks': 592,
#  'easier': 587,
#  'low': 587,
#  'july': 586,
#  'opinion': 586,
#  'turn': 585,
#  'means': 583,
#  'noticed': 580,
#  'skip': 579,
#  'admission': 579,
#  'treat': 577,
#  'biggest': 577,
#  'heart': 574,
#  'weekday': 574,
#  'hardly': 574,
#  'daughters': 573,
#  'watched': 572,
#  'shame': 571,
#  'variety': 569,
#  'white': 569,
#  'difference': 569,
#  'turned': 569,
#  'cream': 569,
#  'hall': 568,
#  'various': 565,
#  'rider': 564,
#  'leaving': 564,
#  'dl': 563,
#  'heard': 563,
#  'recommended': 561,
#  'play': 561,
#  'refurbishment': 560,
#  'town': 560,
#  'fastpasses': 559,
#  '30pm': 559,
#  'pleasant': 559,
#  'month': 556,
#  'buying': 555,
#  'total': 553,
#  'weekends': 553,
#  'card': 552,
#  'bottles': 552,
#  'boat': 551,
#  'cut': 551,
#  'apart': 548,
#  'generally': 546,
#  'literally': 546,
#  'example': 545,
#  'middle': 542,
#  'sad': 541,
#  'haven': 541,
#  'job': 541,
#  'mean': 540,
#  'visits': 540,
#  'airport': 540,
#  'interesting': 539,
#  'didnt': 539,
#  'massive': 538,
#  'warm': 538,
#  'particularly': 538,
#  'starts': 537,
#  'surprise': 535,
#  'saved': 534,
#  'standard': 534,
#  'disabled': 533,
#  'decent': 533,
#  'imagine': 532,
#  'bay': 531,
#  'experiences': 531,
#  'railroad': 530,
#  'thank': 530,
#  'considering': 530,
#  'guest': 529,
#  'friend': 528,
#  'slightly': 528,
#  'catch': 528,
#  'normal': 528,
#  '13': 525,
#  'seats': 524,
#  'activities': 523,
#  'ratatouille': 523,
#  'costs': 523,
#  'comes': 523,
#  'terrible': 521,
#  'goofy': 521,
#  'store': 521,
#  'multiple': 520,
#  'que': 520,
#  'december': 520,
#  'information': 520,
#  'paint': 518,
#  'river': 516,
#  'flight': 516,
#  'bother': 512,
#  'push': 511,
#  'facilities': 510,
#  'fans': 509,
#  'technical': 509,
#  'opportunity': 508,
#  'issues': 508,
#  'negative': 508,
#  'fountains': 508,
#  'maintained': 507,
#  'fair': 506,
#  'add': 505,
#  'items': 504,
#  'speak': 502,
#  'awful': 501,
#  'sunny': 501,
#  'europe': 498,
#  'pre': 497,
#  'adventureland': 496,
#  'booking': 496,
#  'basically': 495,
#  'helped': 492,
#  'filled': 491,
#  'local': 491,
#  'hyperspace': 490,
#  'thoroughly': 490,
#  'missing': 490,
#  'unique': 490,
#  'location': 489,
#  '14': 489,
#  'aware': 487,
#  'max': 487,
#  'nemo': 485,
#  'uk': 485,
#  'january': 484,
#  'faces': 484,
#  'burger': 484,
#  'event': 482,
#  'finding': 479,
#  'package': 479,
#  'comparison': 477,
#  'classic': 477,
#  'stopped': 476,
#  'guide': 475,
#  'offered': 474,
#  'moving': 474,
#  'smoke': 473,
#  'pizza': 473,
#  'recently': 472,
#  'feet': 472,
#  'rush': 472,
#  'chicken': 470,
#  'seat': 469,
#  'pack': 469,
#  'movie': 468,
#  'vouchers': 467,
#  'happened': 467,
#  'consider': 466,
#  'june': 465,
#  'ocean': 463,
#  'boy': 463,
#  'chips': 462,
#  'worse': 462,
#  '2nd': 460,
#  'teenagers': 459,
#  'riding': 458,
#  'drop': 458,
#  'winnie': 458,
#  'gives': 456,
#  '1st': 456,
#  'stood': 454,
#  'reservations': 454,
#  'manage': 453,
#  'mor': 453,
#  'september': 452,
#  'america': 452,
#  'travelling': 452,
#  'parts': 451,
#  'thinking': 451,
#  'added': 450,
#  'march': 450,
#  'grown': 450,
#  'frontierland': 449,
#  'snack': 448,
#  'winter': 448,
#  'sign': 447,
#  'honestly': 447,
#  'stores': 446,
#  'budget': 446,
#  'prior': 444,
#  'hongkong': 443,
#  'lands': 443,
#  'enjoying': 442,
#  'wheelchair': 442,
#  'alot': 441,
#  'carry': 441,
#  'exit': 438,
#  'stars': 438,
#  'previous': 438,
#  'eyes': 437,
#  'color': 437,
#  'travelled': 436,
#  '70': 435,
#  'control': 434,
#  'charge': 434,
#  'safe': 433,
#  'notice': 433,
#  'crush': 433,
#  'tuesday': 430,
#  'rooms': 430,
#  'headed': 430,
#  'door': 429,
#  'thursday': 427,
#  'wet': 427,
#  'plaza': 427,
#  'autopia': 427,
#  'choices': 426,
#  'research': 426,
#  'sorry': 424,
#  'ups': 424,
#  'gift': 424,
#  'golden': 424,
#  'regular': 423,
#  'air': 423,
#  'wild': 423,
#  'dirty': 423,
#  'greet': 423,
#  'seating': 422,
#  'lifetime': 421,
#  'gulch': 421,
#  'excitement': 420,
#  'cute': 419,
#  'sell': 418,
#  'offers': 418,
#  'ques': 417,
#  'type': 417,
#  'grab': 417,
#  'signs': 416,
#  'level': 415,
#  'suitable': 415,
#  'november': 414,
#  'downside': 413,
#  'fairly': 412,
#  'polite': 412,
#  '3rd': 410,
#  'decorated': 410,
#  'disappoint': 410,
#  'organised': 409,
#  'happen': 406,
#  'sort': 406,
#  'points': 406,
#  'future': 403,
#  'memorable': 403,
#  'alice': 403,
#  'sat': 402,
#  'impossible': 402,
#  'advise': 402,
#  'laser': 402,
#  'fault': 402,
#  'cinderella': 401,
#  'nightmare': 401,
#  'management': 398,
#  'based': 397,
#  'entering': 397,
#  'april': 397,
#  'schedule': 394,
#  'closes': 393,
#  '80': 392,
#  'drive': 392,
#  'mainly': 391,
#  'discount': 391,
#  'chose': 390,
#  'tram': 390,
#  'download': 390,
#  'style': 389,
#  'coasters': 389,
#  'important': 389,
#  'returning': 388,
#  'complaint': 388,
#  'unlike': 388,
#  'bored': 387,
#  'grandchildren': 387,
#  'explore': 386,
#  'sitting': 386,
#  'dog': 385,
#  'outlets': 385,
#  'details': 384,
#  'thrilling': 383}
